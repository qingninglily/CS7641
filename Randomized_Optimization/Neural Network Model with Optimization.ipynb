# %%
from IPython.core.display import display, HTML # for some notebook formatting.

import mlrose_hiive
import numpy as np
import logging
import networkx as nx
import matplotlib.pyplot as plt
import string
from sklearn.metrics import *
from sklearn.metrics import roc_auc_score
import sklearn

from ast import literal_eval
import chess

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics import accuracy_score
from mlrose_hiive import QueensGenerator, MaxKColorGenerator, TSPGenerator
from mlrose_hiive import RHCRunner, SARunner, GARunner, MIMICRunner, NNGSRunner

# %%
bc=pd.read_csv('Breast_cancer_data.csv')
#https://www.kaggle.com/merishnasuwal/breast-cancer-prediction-dataset
bc=bc[bc.isnull().any(axis=1)==False]

# %%
X = bc.loc[:, bc.columns != 'diagnosis']
y = bc.loc[:, bc.columns == 'diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123, shuffle=True, stratify=y)

# %%
X_train
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 405        10.94         18.59           70.39      370.0          0.10040
# 568         7.76         24.54           47.92      181.0          0.05263
# 99         14.42         19.77           94.48      642.5          0.09752
# 263        15.61         19.38          100.00      758.6          0.07840
# 420        11.57         19.04           74.20      409.7          0.08546
# ..           ...           ...             ...        ...              ...
# 276        11.33         14.16           71.79      396.6          0.09379
# 429        12.72         17.67           80.98      501.3          0.07896
# 15         14.54         27.54           96.73      658.8          0.11390
# 497        12.47         17.31           80.45      480.1          0.08928
# 242        11.30         18.19           73.93      389.4          0.09592
#
# [455 rows x 5 columns]

# %%
def show_performance_metrics(y_pred, y_test, y_prob):
    accuracy = accuracy_score(y_pred, y_test)
    precision = precision_score(y_pred, y_test)
    recall = recall_score(y_pred, y_test)
    f1score = f1_score(y_pred, y_test)
    roc_auc_score=sklearn.metrics.roc_auc_score(y_test, y_prob)
    print(("Accuracy: "+str(accuracy)))
    print(("Precision: "+str(precision)))
    print(("Recall: "+str(recall)))
    print(("F1-score: "+str(f1score)))
    print('ROC AUC Score: '+str(roc_auc_score))

# %% [markdown]
# ### Randomized Hill Climbing

# %%
grid_search_parameters = {
    'max_iters': [1000],                          # nn params
    'learning_rate': [0.001, 0.01, 0.1],                       # nn params
    'activation': [mlrose_hiive.relu, mlrose_hiive.sigmoid],            # nn params
    'restarts': [1],                             # rhc params
}

nnr = NNGSRunner(
    x_train=X_train,
    y_train=y_train,
    x_test=X_test,
    y_test=y_test,
    experiment_name='nn_rhc',
    algorithm=mlrose_hiive.algorithms.rhc.random_hill_climb,
    grid_search_parameters=grid_search_parameters,
    iteration_list=[1, 10, 50, 100, 250, 500, 1000],
    hidden_layer_sizes=[[1]],
    bias=True,
    early_stopping=True,
    clip_max=5,
    max_attempts=500,
    n_jobs=5,
    seed=123456,
    output_directory=None
)


run_stats_df, curves_df, cv_results_df, grid_search_cv = nnr.run()
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed:   15.2s finished

# %%
y_test_pred = grid_search_cv.predict(X_test)
y_test_accuracy = accuracy_score(y_test, y_test_pred)
print(y_test_accuracy)
# Out:
# 0.3684210526315789

# %%
y_train_pred = grid_search_cv.predict(X_train)
y_train_accuracy = accuracy_score(y_train, y_train_pred)
print(y_train_accuracy)
# Out:
# 0.37362637362637363

# %%
y_test_prob=grid_search_cv.predict_proba(X_test)
show_performance_metrics(y_test_pred, y_test, y_test_prob)
# Out:
# Accuracy: 0.3684210526315789
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# ROC AUC Score: 0.5

# %%
run_stats_df
# Out:
#     Iteration    Fitness  FEvals      Time  \
# 0           0  18.610375       1  0.002927
# 1           1  18.544783       3  0.009425
# 2          10  17.998676      15  0.023756
# 3          50   0.867364      78  0.084979
# 4         100   0.550463     152  0.158878
# 5         250   0.545546     330  0.323916
# 6         500   0.543107     621  0.576021
# 7        1000   0.542501    1176  1.181279
# 8           0  18.610375    1176  1.187318
# 9           1   1.019951    1178  1.193634
# 10         10   1.009470    1194  1.213317
# 11         50   0.823562    1250  1.281044
# 12        100   0.743272    1317  1.361103
# 13        250   0.693147    1476  1.580909
# 14        500   0.693147    1726  1.970561
# 15       1000   0.693147    1839  2.163522
#
#                                                 State  max_iters  \
# 0   [-0.7460603339237981, 0.933435676964006, -0.47...       1000
# 1   [-0.7460603339237981, 0.833435676964006, -0.47...       1000
# 2   [-0.7460603339237981, 0.833435676964006, -0.67...       1000
# 3   [-0.8460603339237981, 0.5334356769640061, -0.9...       1000
# 4   [-1.0460603339237982, 0.1334356769640061, -1.1...       1000
# 5   [-1.4460603339237985, 0.3334356769640061, -1.1...       1000
# 6   [-1.6460603339237987, 0.633435676964006, -1.17...       1000
# 7   [-1.7460603339237988, 0.633435676964006, -1.17...       1000
# 8   [-0.7460603339237981, 0.933435676964006, -0.47...       1000
# 9   [-0.7460603339237981, 0.933435676964006, -0.47...       1000
# 10  [-0.9460603339237981, 0.733435676964006, -0.57...       1000
# 11  [-1.2460603339237983, 0.4334356769640061, -0.7...       1000
# 12  [-1.4460603339237985, 0.1334356769640061, -1.1...       1000
# 13  [-1.5460603339237986, -0.16656432303599392, -1...       1000
# 14  [-1.5460603339237986, -0.16656432303599392, -1...       1000
# 15  [-1.5460603339237986, -0.16656432303599392, -1...       1000
#
#     learning_rate  restarts  \
# 0           0.001         1
# 1           0.001         1
# 2           0.001         1
# 3           0.001         1
# 4           0.001         1
# 5           0.001         1
# 6           0.001         1
# 7           0.001         1
# 8           0.001         1
# 9           0.001         1
# 10          0.001         1
# 11          0.001         1
# 12          0.001         1
# 13          0.001         1
# 14          0.001         1
# 15          0.001         1
#
#                                            init_state algorithm activation  \
# 0   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 1   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 2   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 3   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 4   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 5   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 6   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 7   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 8   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 9   [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 10  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 11  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 12  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 13  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 14  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
# 15  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc       relu
#
#     bias  early_stopping  clip_max hidden_layer_sizes  learning_rate_init  \
# 0   True            True         5                [1]                 0.1
# 1   True            True         5                [1]                 0.1
# 2   True            True         5                [1]                 0.1
# 3   True            True         5                [1]                 0.1
# 4   True            True         5                [1]                 0.1
# 5   True            True         5                [1]                 0.1
# 6   True            True         5                [1]                 0.1
# 7   True            True         5                [1]                 0.1
# 8   True            True         5                [1]                 0.1
# 9   True            True         5                [1]                 0.1
# 10  True            True         5                [1]                 0.1
# 11  True            True         5                [1]                 0.1
# 12  True            True         5                [1]                 0.1
# 13  True            True         5                [1]                 0.1
# 14  True            True         5                [1]                 0.1
# 15  True            True         5                [1]                 0.1
#
#     max_attempts  current_restart
# 0            500                0
# 1            500                0
# 2            500                0
# 3            500                0
# 4            500                0
# 5            500                0
# 6            500                0
# 7            500                0
# 8            500                1
# 9            500                1
# 10           500                1
# 11           500                1
# 12           500                1
# 13           500                1
# 14           500                1
# 15           500                1

# %%
curves_df.iloc[1000:]
# Out:
#       Iteration      Time   Fitness  FEvals  max_iters  learning_rate  \
# 1000       1000  1.181279  0.542501  1176.0       1000          0.001
# 1001          1  0.009425  1.019951  1178.0       1000          0.001
# 1002          2  0.014250  1.019946  1180.0       1000          0.001
# 1003          3  0.015089  1.018933  1182.0       1000          0.001
# 1004          4  0.015920  1.017952  1184.0       1000          0.001
# ...         ...       ...       ...     ...        ...            ...
# 1609        609  0.698825  0.693147  1835.0       1000          0.001
# 1610        610  0.699860  0.693147  1836.0       1000          0.001
# 1611        611  0.701453  0.693147  1837.0       1000          0.001
# 1612        612  0.702489  0.693147  1838.0       1000          0.001
# 1613        613  0.703522  0.693147  1839.0       1000          0.001
#
#       restarts                                         init_state algorithm  \
# 1000         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1001         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1002         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1003         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1004         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# ...        ...                                                ...       ...
# 1609         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1610         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1611         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1612         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1613         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
#
#      activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 1000       relu  True            True         5                [1]
# 1001       relu  True            True         5                [1]
# 1002       relu  True            True         5                [1]
# 1003       relu  True            True         5                [1]
# 1004       relu  True            True         5                [1]
# ...         ...   ...             ...       ...                ...
# 1609       relu  True            True         5                [1]
# 1610       relu  True            True         5                [1]
# 1611       relu  True            True         5                [1]
# 1612       relu  True            True         5                [1]
# 1613       relu  True            True         5                [1]
#
#       learning_rate_init  max_attempts  current_restart
# 1000                 0.1           500                0
# 1001                 0.1           500                1
# 1002                 0.1           500                1
# 1003                 0.1           500                1
# 1004                 0.1           500                1
# ...                  ...           ...              ...
# 1609                 0.1           500                1
# 1610                 0.1           500                1
# 1611                 0.1           500                1
# 1612                 0.1           500                1
# 1613                 0.1           500                1
#
# [614 rows x 17 columns]

# %%
cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.796252      0.030805         0.000929        0.000066
# 1       2.547320      0.039735         0.000753        0.000034
# 2       2.910599      0.029098         0.000743        0.000113
# 3       1.709919      0.109861         0.001158        0.000365
# 4       2.007682      0.077754         0.000818        0.000088
# 5       1.838422      0.160023         0.001012        0.000094
#
#   param_activation param_hidden_layer_sizes  param_learning_rate  \
# 0             relu                      [1]                0.001
# 1             relu                      [1]                0.010
# 2             relu                      [1]                0.100
# 3          sigmoid                      [1]                0.001
# 4          sigmoid                      [1]                0.010
# 5          sigmoid                      [1]                0.100
#
#    param_max_iters  param_restarts  \
# 0             1000               1
# 1             1000               1
# 2             1000               1
# 3             1000               1
# 4             1000               1
# 5             1000               1
#
#                                               params  ...  mean_test_score  \
# 0  {'activation': <function relu at 0x7fafd35311f...  ...              0.5
# 1  {'activation': <function relu at 0x7fafd35311f...  ...              0.5
# 2  {'activation': <function relu at 0x7fafd35311f...  ...              0.5
# 3  {'activation': <function sigmoid at 0x7fafd353...  ...              0.5
# 4  {'activation': <function sigmoid at 0x7fafd353...  ...              0.5
# 5  {'activation': <function sigmoid at 0x7fafd353...  ...              0.5
#
#    std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0             0.0                1                 0.5                 0.5
# 1             0.0                1                 0.5                 0.5
# 2             0.0                1                 0.5                 0.5
# 3             0.0                1                 0.5                 0.5
# 4             0.0                1                 0.5                 0.5
# 5             0.0                1                 0.5                 0.5
#
#    split2_train_score  split3_train_score  split4_train_score  \
# 0                 0.5                 0.5                 0.5
# 1                 0.5                 0.5                 0.5
# 2                 0.5                 0.5                 0.5
# 3                 0.5                 0.5                 0.5
# 4                 0.5                 0.5                 0.5
# 5                 0.5                 0.5                 0.5
#
#    mean_train_score  std_train_score
# 0               0.5              0.0
# 1               0.5              0.0
# 2               0.5              0.0
# 3               0.5              0.0
# 4               0.5              0.0
# 5               0.5              0.0
#
# [6 rows x 25 columns]

# %%
best_fitness = run_stats_df['Fitness'].min()
best_runs = run_stats_df[run_stats_df['Fitness'] == best_fitness]
result1=best_runs[['Fitness','FEvals','Time','activation','learning_rate']]
result1['Algorithm']='Randomized Hill Climbing'
best_runs
# Out:
#    Iteration   Fitness  FEvals      Time  \
# 7       1000  0.542501    1176  1.181279
#
#                                                State  max_iters  \
# 7  [-1.7460603339237988, 0.633435676964006, -1.17...       1000
#
#    learning_rate  restarts                                         init_state  \
# 7          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
#
#   algorithm activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 7       rhc       relu  True            True         5                [1]
#
#    learning_rate_init  max_attempts  current_restart
# 7                 0.1           500                0

# %%
best_activation=best_runs['activation'].iloc[0]
best_lr=best_runs['learning_rate'].iloc[0]
best_current_start=best_runs['current_restart'].iloc[0]

# %%
opt_curve=curves_df[(curves_df['activation']==best_activation) & (curves_df['learning_rate']==best_lr) & (curves_df['current_restart']==best_current_start)]
opt_curve
# Out:
#       Iteration      Time    Fitness  FEvals  max_iters  learning_rate  \
# 0             0  0.002927  18.544783     1.0       1000          0.001
# 1             1  0.009425  18.544783     3.0       1000          0.001
# 2             2  0.014250  18.544783     4.0       1000          0.001
# 3             3  0.015089  18.544783     5.0       1000          0.001
# 4             4  0.015920  18.544783     6.0       1000          0.001
# ...         ...       ...        ...     ...        ...            ...
# 996         996  1.176306   0.542501  1172.0       1000          0.001
# 997         997  1.177548   0.542501  1173.0       1000          0.001
# 998         998  1.178791   0.542501  1174.0       1000          0.001
# 999         999  1.180035   0.542501  1175.0       1000          0.001
# 1000       1000  1.181279   0.542501  1176.0       1000          0.001
#
#       restarts                                         init_state algorithm  \
# 0            1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1            1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 2            1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 3            1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 4            1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# ...        ...                                                ...       ...
# 996          1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 997          1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 998          1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 999          1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
# 1000         1  [-0.7460603339237981, 0.933435676964006, -0.47...       rhc
#
#      activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 0          relu  True            True         5                [1]
# 1          relu  True            True         5                [1]
# 2          relu  True            True         5                [1]
# 3          relu  True            True         5                [1]
# 4          relu  True            True         5                [1]
# ...         ...   ...             ...       ...                ...
# 996        relu  True            True         5                [1]
# 997        relu  True            True         5                [1]
# 998        relu  True            True         5                [1]
# 999        relu  True            True         5                [1]
# 1000       relu  True            True         5                [1]
#
#       learning_rate_init  max_attempts  current_restart
# 0                    0.1           500                0
# 1                    0.1           500                0
# 2                    0.1           500                0
# 3                    0.1           500                0
# 4                    0.1           500                0
# ...                  ...           ...              ...
# 996                  0.1           500                0
# 997                  0.1           500                0
# 998                  0.1           500                0
# 999                  0.1           500                0
# 1000                 0.1           500                0
#
# [1001 rows x 17 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('random_hill_climb')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim([0,15])
plt.legend()
plt.title('random_hill_climb')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('random_hill_climb')
plt.show()

# %% [markdown]
# ### Simulated Annealing

# %%
grid_search_parameters = {
    'max_iters': [1000],                          # nn params
    'learning_rate': [0.001, 0.01, 0.1],                       # nn params
    'activation': [mlrose_hiive.relu, mlrose_hiive.sigmoid],            # nn params
    'restarts': [1],                             # rhc params
}

nnr = NNGSRunner(
    x_train=X_train,
    y_train=y_train,
    x_test=X_test,
    y_test=y_test,
    experiment_name='nn_sa',
    algorithm=mlrose_hiive.algorithms.sa.simulated_annealing,
    grid_search_parameters=grid_search_parameters,
    iteration_list=[1, 10, 50, 100, 250, 500, 1000],
    hidden_layer_sizes=[[1]],
    bias=True,
    early_stopping=True,
    clip_max=5,
    max_attempts=500,
    n_jobs=5,
    seed=123456,
    output_directory=None
)


run_stats_df, curves_df, cv_results_df, grid_search_cv = nnr.run()
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed:   12.5s finished

# %%
y_test_pred = grid_search_cv.predict(X_test)
y_test_accuracy = accuracy_score(y_test, y_test_pred)
print(y_test_accuracy)
# Out:
# 0.8771929824561403

# %%
y_train_pred = grid_search_cv.predict(X_train)
y_train_accuracy = accuracy_score(y_train, y_train_pred)
print(y_train_accuracy)
# Out:
# 0.8681318681318682

# %%
y_test_prob=grid_search_cv.predict_proba(X_test)
show_performance_metrics(y_test_pred, y_test, y_test_prob)
# Out:
# Accuracy: 0.8771929824561403
# Precision: 1.0
# Recall: 0.8372093023255814
# F1-score: 0.9113924050632911
# ROC AUC Score: 0.9381613756613758

# %%
best_fitness = run_stats_df['Fitness'].min()
best_runs = run_stats_df[run_stats_df['Fitness'] == best_fitness]
result2=best_runs[['Fitness','FEvals','Time','activation','learning_rate']]
result2['Algorithm']='Simulated Annealing'
best_runs
# Out:
#    Iteration   Fitness  FEvals      Time  \
# 7       1000  0.468102    1705  2.053323
#
#                                                State  max_iters  \
# 7  [-2.3460603339237993, -1.266564323035994, 2.12...       1000
#
#    learning_rate  restarts                                         init_state  \
# 7          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
#
#   algorithm activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 7        sa       relu  True            True         5                [1]
#
#    learning_rate_init  max_attempts
# 7                 0.1           500

# %%
best_activation=best_runs['activation'].iloc[0]
best_lr=best_runs['learning_rate'].iloc[0]
best_current_start=best_runs['restarts'].iloc[0]

# %%
opt_curve=curves_df[(curves_df['activation']==best_activation) & (curves_df['learning_rate']==best_lr) & (curves_df['restarts']==best_current_start)]
opt_curve
# Out:
#       Iteration      Time    Fitness  FEvals  max_iters  learning_rate  \
# 0             0  0.001867  18.544783     2.0       1000          0.001
# 1             1  0.006630  18.544783     4.0       1000          0.001
# 2             2  0.011493  18.797396     6.0       1000          0.001
# 3             3  0.012240  18.797396     7.0       1000          0.001
# 4             4  0.013850  18.797064     9.0       1000          0.001
# ...         ...       ...        ...     ...        ...            ...
# 996         996  2.043845   0.468166  1700.0       1000          0.001
# 997         997  2.046752   0.468102  1702.0       1000          0.001
# 998         998  2.048822   0.468102  1703.0       1000          0.001
# 999         999  2.050824   0.468102  1704.0       1000          0.001
# 1000       1000  2.053323   0.468102  1705.0       1000          0.001
#
#       restarts                                         init_state algorithm  \
# 0            1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 1            1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 2            1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 3            1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 4            1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# ...        ...                                                ...       ...
# 996          1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 997          1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 998          1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 999          1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
# 1000         1  [-0.7460603339237981, 0.933435676964006, -0.47...        sa
#
#      activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 0          relu  True            True         5                [1]
# 1          relu  True            True         5                [1]
# 2          relu  True            True         5                [1]
# 3          relu  True            True         5                [1]
# 4          relu  True            True         5                [1]
# ...         ...   ...             ...       ...                ...
# 996        relu  True            True         5                [1]
# 997        relu  True            True         5                [1]
# 998        relu  True            True         5                [1]
# 999        relu  True            True         5                [1]
# 1000       relu  True            True         5                [1]
#
#       learning_rate_init  max_attempts
# 0                    0.1           500
# 1                    0.1           500
# 2                    0.1           500
# 3                    0.1           500
# 4                    0.1           500
# ...                  ...           ...
# 996                  0.1           500
# 997                  0.1           500
# 998                  0.1           500
# 999                  0.1           500
# 1000                 0.1           500
#
# [1001 rows x 16 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('simulated_annealing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim([0,15])
plt.legend()
plt.title('simulated_annealing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('simulated_annealing')
plt.show()

# %% [markdown]
# ### Generic Algorithm

# %%
grid_search_parameters = {
    'max_iters': [1000],                          # nn params
    'learning_rate': [0.001, 0.01, 0.1],                       # nn params
    'activation': [mlrose_hiive.relu, mlrose_hiive.sigmoid],            # nn params
    'restarts': [1],                             # rhc params
}

nnr = NNGSRunner(
    x_train=X_train,
    y_train=y_train,
    x_test=X_test,
    y_test=y_test,
    experiment_name='nn_ga',
    algorithm=mlrose_hiive.algorithms.ga.genetic_alg,
    grid_search_parameters=grid_search_parameters,
    iteration_list=[1, 10, 50, 100, 250, 500, 1000],
    hidden_layer_sizes=[[1]],
    bias=True,
    early_stopping=True,
    clip_max=5,
    max_attempts=500,
    n_jobs=5,
    seed=123456,
    output_directory=None
)


run_stats_df, curves_df, cv_results_df, grid_search_cv = nnr.run()
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed: 13.2min finished

# %%
y_test_pred = grid_search_cv.predict(X_test)
y_test_accuracy = accuracy_score(y_test, y_test_pred)
print(y_test_accuracy)
# Out:
# 0.8859649122807017

# %%
y_train_pred = grid_search_cv.predict(X_train)
y_train_accuracy = accuracy_score(y_train, y_train_pred)
print(y_train_accuracy)
# Out:
# 0.8747252747252747

# %%
y_test_prob=grid_search_cv.predict_proba(X_test)
show_performance_metrics(y_test_pred, y_test, y_test_prob)
# Out:
# Accuracy: 0.8859649122807017
# Precision: 0.9583333333333334
# Recall: 0.8734177215189873
# F1-score: 0.913907284768212
# ROC AUC Score: 0.9408068783068784

# %%
best_fitness = run_stats_df['Fitness'].min()
best_runs = run_stats_df[run_stats_df['Fitness'] == best_fitness]
result3=best_runs[['Fitness','FEvals','Time','activation','learning_rate']]
result3['Algorithm']='Generic Algorithm'
best_runs
# Out:
#    Iteration   Fitness  FEvals        Time  \
# 7       1000  0.452513  201279  114.867163
#
#                                                State  max_iters  \
# 7  [4.99981117874059, -4.512517848411523, 4.71232...       1000
#
#    learning_rate  restarts                                         init_state  \
# 7          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
#
#   algorithm activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 7        ga    sigmoid  True            True         5                [1]
#
#    learning_rate_init  max_attempts
# 7                 0.1           500

# %%
best_activation=best_runs['activation'].iloc[0]
best_lr=best_runs['learning_rate'].iloc[0]
best_current_start=best_runs['restarts'].iloc[0]

# %%
opt_curve=curves_df[(curves_df['activation']==best_activation) & (curves_df['learning_rate']==best_lr) & (curves_df['restarts']==best_current_start)]
opt_curve
# Out:
#       Iteration        Time   Fitness    FEvals  max_iters  learning_rate  \
# 0             0    0.114991  0.600667     201.0       1000          0.001
# 1             1    0.243898  0.600667     403.0       1000          0.001
# 2             2    0.375863  0.600667     604.0       1000          0.001
# 3             3    0.493373  0.570030     806.0       1000          0.001
# 4             4    0.609599  0.570030    1007.0       1000          0.001
# ...         ...         ...       ...       ...        ...            ...
# 996         996  114.408121  0.452513  200475.0       1000          0.001
# 997         997  114.523631  0.452513  200676.0       1000          0.001
# 998         998  114.637477  0.452513  200877.0       1000          0.001
# 999         999  114.752822  0.452513  201078.0       1000          0.001
# 1000       1000  114.867163  0.452513  201279.0       1000          0.001
#
#       restarts                                         init_state algorithm  \
# 0            1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 1            1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 2            1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 3            1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 4            1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# ...        ...                                                ...       ...
# 996          1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 997          1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 998          1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 999          1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
# 1000         1  [-0.7460603339237981, 0.933435676964006, -0.47...        ga
#
#      activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 0       sigmoid  True            True         5                [1]
# 1       sigmoid  True            True         5                [1]
# 2       sigmoid  True            True         5                [1]
# 3       sigmoid  True            True         5                [1]
# 4       sigmoid  True            True         5                [1]
# ...         ...   ...             ...       ...                ...
# 996     sigmoid  True            True         5                [1]
# 997     sigmoid  True            True         5                [1]
# 998     sigmoid  True            True         5                [1]
# 999     sigmoid  True            True         5                [1]
# 1000    sigmoid  True            True         5                [1]
#
#       learning_rate_init  max_attempts
# 0                    0.1           500
# 1                    0.1           500
# 2                    0.1           500
# 3                    0.1           500
# 4                    0.1           500
# ...                  ...           ...
# 996                  0.1           500
# 997                  0.1           500
# 998                  0.1           500
# 999                  0.1           500
# 1000                 0.1           500
#
# [1001 rows x 16 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('genetic_alg')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim([0,400])
plt.legend()
plt.title('genetic_alg')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('genetic_alg')
plt.show()

# %% [markdown]
# ### Gradient Descent

# %%
grid_search_parameters = {
    'max_iters': [1000],                          # nn params
    'learning_rate': [0.001, 0.01, 0.1],                       # nn params
    'activation': [mlrose_hiive.relu, mlrose_hiive.sigmoid],            # nn params
    'restarts': [1],                             # rhc params
}

nnr_benchmark = NNGSRunner(
    x_train=X_train,
    y_train=y_train,
    x_test=X_test,
    y_test=y_test,
    experiment_name='nn_ga',
    algorithm=mlrose_hiive.algorithms.gd.gradient_descent,
    grid_search_parameters=grid_search_parameters,
    iteration_list=[1, 10, 50, 100, 250, 500, 1000],
    hidden_layer_sizes=[[1]],
    bias=True,
    early_stopping=True,
    clip_max=5,
    max_attempts=500,
    n_jobs=5,
    seed=123456,
    output_directory=None
)


run_stats_df, curves_df, cv_results_df, grid_search_cv = nnr_benchmark.run()
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed:    6.3s finished

# %%
y_test_pred = grid_search_cv.predict(X_test)
y_test_accuracy = accuracy_score(y_test, y_test_pred)
print(y_test_accuracy)
# Out:
# 0.3684210526315789

# %%
y_train_pred = grid_search_cv.predict(X_train)
y_train_accuracy = accuracy_score(y_train, y_train_pred)
print(y_train_accuracy)
# Out:
# 0.37362637362637363

# %%
y_test_prob=grid_search_cv.predict_proba(X_test)
show_performance_metrics(y_test_pred, y_test, y_test_prob)
# Out:
# Accuracy: 0.3684210526315789
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# ROC AUC Score: 0.5

# %%
best_fitness = run_stats_df['Fitness'].min()
best_runs = run_stats_df[run_stats_df['Fitness'] == best_fitness]
result4=best_runs[['Fitness','FEvals','Time','activation','learning_rate']]
result4['Algorithm']='Gradient Descent'
best_runs
# Out:
#    Iteration   Fitness FEvals      Time  \
# 2         10  0.693147   None  0.018369
# 3         50  0.693147   None  0.066498
# 4        100  0.693147   None  0.127153
# 5        250  0.693147   None  0.336339
# 6        500  0.693147   None  0.679021
# 7       1000  0.693147   None  0.684107
#
#                                                State  max_iters  \
# 2  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
# 3  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
# 4  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
# 5  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
# 6  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
# 7  [-5.0, -5.0, -5.0, -5.0, -0.5014723627269508, ...       1000
#
#    learning_rate  restarts                                         init_state  \
# 2          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
# 3          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
# 4          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
# 5          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
# 6          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
# 7          0.001         1  [-0.7460603339237981, 0.933435676964006, -0.47...
#
#   algorithm activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 2        gd       relu  True            True         5                [1]
# 3        gd       relu  True            True         5                [1]
# 4        gd       relu  True            True         5                [1]
# 5        gd       relu  True            True         5                [1]
# 6        gd       relu  True            True         5                [1]
# 7        gd       relu  True            True         5                [1]
#
#    learning_rate_init  max_attempts
# 2                 0.1           500
# 3                 0.1           500
# 4                 0.1           500
# 5                 0.1           500
# 6                 0.1           500
# 7                 0.1           500

# %%
best_activation=best_runs['activation'].iloc[0]
best_lr=best_runs['learning_rate'].iloc[0]
best_current_start=best_runs['restarts'].iloc[0]

# %%
opt_curve=curves_df[(curves_df['activation']==best_activation) & (curves_df['learning_rate']==best_lr) & (curves_df['restarts']==best_current_start)]
opt_curve
# Out:
#      Iteration      Time    Fitness  FEvals  max_iters  learning_rate  \
# 0            0  0.002080  18.610375     NaN       1000          0.001
# 1            1  0.005819  18.610375     3.0       1000          0.001
# 2            2  0.009301   0.693147     5.0       1000          0.001
# 3            3  0.010421   0.693147     7.0       1000          0.001
# 4            4  0.011541   0.693147     9.0       1000          0.001
# ..         ...       ...        ...     ...        ...            ...
# 497        497  0.674528   0.693147   995.0       1000          0.001
# 498        498  0.676169   0.693147   997.0       1000          0.001
# 499        499  0.677593   0.693147   999.0       1000          0.001
# 500        500  0.679021   0.693147  1001.0       1000          0.001
# 501        501  0.684107   0.693147  1003.0       1000          0.001
#
#      restarts                                         init_state algorithm  \
# 0           1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 1           1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 2           1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 3           1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 4           1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# ..        ...                                                ...       ...
# 497         1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 498         1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 499         1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 500         1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
# 501         1  [-0.7460603339237981, 0.933435676964006, -0.47...        gd
#
#     activation  bias  early_stopping  clip_max hidden_layer_sizes  \
# 0         relu  True            True         5                [1]
# 1         relu  True            True         5                [1]
# 2         relu  True            True         5                [1]
# 3         relu  True            True         5                [1]
# 4         relu  True            True         5                [1]
# ..         ...   ...             ...       ...                ...
# 497       relu  True            True         5                [1]
# 498       relu  True            True         5                [1]
# 499       relu  True            True         5                [1]
# 500       relu  True            True         5                [1]
# 501       relu  True            True         5                [1]
#
#      learning_rate_init  max_attempts
# 0                   0.1           500
# 1                   0.1           500
# 2                   0.1           500
# 3                   0.1           500
# 4                   0.1           500
# ..                  ...           ...
# 497                 0.1           500
# 498                 0.1           500
# 499                 0.1           500
# 500                 0.1           500
# 501                 0.1           500
#
# [502 rows x 16 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('genetic_alg')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim([0,15])
plt.legend()
plt.title('genetic_alg')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('genetic_alg')
plt.show()

# %% [markdown]
# ### Algorithm Comparison

# %%
results=pd.concat([result1,result2,result3])

# %%
results
# Out:
#     Fitness  FEvals        Time activation  learning_rate  \
# 7  0.542501    1176    1.181279       relu          0.001
# 7  0.468102    1705    2.053323       relu          0.001
# 7  0.452513  201279  114.867163    sigmoid          0.001
#
#                   Algorithm
# 7  Randomized Hill Climbing
# 7       Simulated Annealing
# 7         Generic Algorithm
