# %%
# !pip install mlrose-hiive
# !pip install chess

# %%
from IPython.core.display import display, HTML # for some notebook formatting.

import mlrose_hiive
import numpy as np
import logging
import networkx as nx
import matplotlib.pyplot as plt
import string


from ast import literal_eval
import chess

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics import accuracy_score
from mlrose_hiive import QueensGenerator, MaxKColorGenerator, TSPGenerator
from mlrose_hiive import RHCRunner, SARunner, GARunner, MIMICRunner, NNGSRunner

# %% [markdown]
# ## Optimization Problem : Queens

# %%
# Generate a new 8-Queen problem using a fixed seed.
problem = QueensGenerator().generate(seed=123456, size=8)

#Initial State
state = [0,1,2,3,4,5,6,7]
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)
board
# Out:
# Board('Q7/1Q6/2Q5/3Q4/4Q3/5Q2/6Q1/7Q w - - 0 1')

# %% [markdown]
# ### Algorithm 1: Randomized Hill Climbing

# %%
rhc = RHCRunner(problem=problem,
                    experiment_name='queen8_rhc',
                    output_directory=None,
                    seed=123,
                    iteration_list=2 ** np.arange(11),
                    max_attempts=500,
                    restart_list=[5, 10, 20, 50, 75, 100])   
# the two data frames will contain the results
df_run_stats, df_run_curves = rhc.run()

# %%
df_run_stats.iloc[:60]
# Out:
#     Iteration  Fitness  FEvals      Time                     State  Restarts  \
# 0           0      9.0       0  0.001209  [6, 5, 6, 2, 4, 2, 6, 1]         5
# 1           1      9.0       1  0.003988  [6, 5, 6, 2, 4, 2, 6, 1]         5
# 2           2      9.0       2  0.005996  [6, 5, 6, 2, 4, 2, 6, 1]         5
# 3           4      8.0       5  0.007955  [1, 5, 6, 2, 4, 2, 6, 1]         5
# 4           8      8.0       9  0.010177  [1, 5, 6, 2, 4, 2, 6, 1]         5
# 5          16      3.0      21  0.014106  [1, 5, 4, 2, 0, 2, 6, 2]         5
# 6          32      3.0      37  0.019095  [1, 5, 4, 2, 0, 2, 6, 2]         5
# 7          64      2.0      70  0.029018  [1, 7, 4, 2, 0, 2, 6, 2]         5
# 8         128      2.0     134  0.047982  [1, 7, 4, 2, 0, 2, 6, 2]         5
# 9         256      2.0     262  0.093355  [1, 7, 4, 2, 0, 2, 6, 2]         5
# 10        512      2.0     518  0.217107  [1, 7, 4, 2, 0, 2, 6, 2]         5
# 11       1024      2.0     565  0.246307  [1, 7, 4, 2, 0, 2, 6, 2]         5
# 12          0      5.0     565  0.248547  [3, 2, 4, 6, 1, 1, 6, 0]         5
# 13          1      5.0     566  0.251062  [3, 2, 4, 6, 1, 1, 6, 0]         5
# 14          2      5.0     567  0.253590  [3, 2, 4, 6, 1, 1, 6, 0]         5
# 15          4      5.0     569  0.256716  [3, 2, 4, 6, 1, 1, 6, 0]         5
# 16          8      5.0     573  0.261237  [3, 2, 4, 6, 1, 1, 6, 0]         5
# 17         16      2.0     583  0.268224  [4, 2, 4, 6, 1, 3, 6, 0]         5
# 18         32      1.0     600  0.280268  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 19         64      1.0     632  0.301961  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 20        128      1.0     696  0.347430  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 21        256      1.0     824  0.450931  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 22        512      1.0    1080  0.745738  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 23       1024      1.0    1087  0.758667  [4, 2, 4, 6, 1, 3, 5, 0]         5
# 24          0      7.0    1087  0.762610  [5, 2, 0, 0, 2, 3, 6, 0]         5
# 25          1      7.0    1088  0.767457  [5, 2, 0, 0, 2, 3, 6, 0]         5
# 26          2      7.0    1089  0.772491  [5, 2, 0, 0, 2, 3, 6, 0]         5
# 27          4      7.0    1091  0.778531  [5, 2, 0, 0, 2, 3, 6, 0]         5
# 28          8      5.0    1096  0.786630  [5, 2, 0, 7, 2, 3, 6, 0]         5
# 29         16      2.0    1106  0.802085  [5, 2, 0, 7, 3, 3, 6, 4]         5
# 30         32      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 31         64      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 32        128      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 33        256      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 34        512      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 35       1024      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
# 36          0      9.0       0  0.000594  [6, 5, 6, 2, 4, 2, 6, 1]        10
# 37          1      9.0       1  0.005515  [6, 5, 6, 2, 4, 2, 6, 1]        10
# 38          2      9.0       2  0.010012  [6, 5, 6, 2, 4, 2, 6, 1]        10
# 39          4      8.0       5  0.015475  [1, 5, 6, 2, 4, 2, 6, 1]        10
# 40          8      8.0       9  0.021400  [1, 5, 6, 2, 4, 2, 6, 1]        10
# 41         16      3.0      21  0.028760  [1, 5, 4, 2, 0, 2, 6, 2]        10
# 42         32      3.0      37  0.038088  [1, 5, 4, 2, 0, 2, 6, 2]        10
# 43         64      2.0      70  0.053286  [1, 7, 4, 2, 0, 2, 6, 2]        10
# 44        128      2.0     134  0.083008  [1, 7, 4, 2, 0, 2, 6, 2]        10
# 45        256      2.0     262  0.150089  [1, 7, 4, 2, 0, 2, 6, 2]        10
# 46        512      2.0     518  0.337922  [1, 7, 4, 2, 0, 2, 6, 2]        10
# 47       1024      2.0     565  0.383571  [1, 7, 4, 2, 0, 2, 6, 2]        10
# 48          0      5.0     565  0.389468  [3, 2, 4, 6, 1, 1, 6, 0]        10
# 49          1      5.0     566  0.395216  [3, 2, 4, 6, 1, 1, 6, 0]        10
# 50          2      5.0     567  0.400799  [3, 2, 4, 6, 1, 1, 6, 0]        10
# 51          4      5.0     569  0.408205  [3, 2, 4, 6, 1, 1, 6, 0]        10
# 52          8      5.0     573  0.417344  [3, 2, 4, 6, 1, 1, 6, 0]        10
# 53         16      2.0     583  0.430165  [4, 2, 4, 6, 1, 3, 6, 0]        10
# 54         32      1.0     600  0.450009  [4, 2, 4, 6, 1, 3, 5, 0]        10
# 55         64      1.0     632  0.484645  [4, 2, 4, 6, 1, 3, 5, 0]        10
# 56        128      1.0     696  0.551278  [4, 2, 4, 6, 1, 3, 5, 0]        10
# 57        256      1.0     824  0.659712  [4, 2, 4, 6, 1, 3, 5, 0]        10
# 31         31  0.018868      3.0    36.0         5       1024                0
# 32         32  0.019095      3.0    37.0         5       1024                0
# 33         33  0.020761      3.0    38.0         5       1024                0
# 34         34  0.021000      3.0    39.0         5       1024                0
# 35         35  0.021235      3.0    40.0         5       1024                0
# 36         36  0.021468      3.0    41.0         5       1024                0
# 37         37  0.021704      3.0    42.0         5       1024                0
# 38         38  0.021941      3.0    43.0         5       1024                0
# 39         39  0.022175      3.0    44.0         5       1024                0
# 40         40  0.022454      3.0    45.0         5       1024                0
# 41         41  0.022788      3.0    46.0         5       1024                0
# 42         42  0.023109      3.0    47.0         5       1024                0
# 43         43  0.023436      3.0    48.0         5       1024                0
# 44         44  0.023877      3.0    49.0         5       1024                0
# 45         45  0.024111      3.0    50.0         5       1024                0
# 46         46  0.024350      3.0    51.0         5       1024                0
# 47         47  0.024589      3.0    52.0         5       1024                0
# 48         48  0.024830      3.0    53.0         5       1024                0
# 49         49  0.025074      3.0    54.0         5       1024                0
# 50         50  0.025313      3.0    55.0         5       1024                0
# 51         51  0.025553      3.0    56.0         5       1024                0
# 52         52  0.025793      3.0    57.0         5       1024                0
# 53         53  0.026042      3.0    58.0         5       1024                0
# 54         54  0.026288      3.0    59.0         5       1024                0
# 55         55  0.026534      3.0    60.0         5       1024                0
# 56         56  0.026779      3.0    61.0         5       1024                0
# 57         57  0.027030      3.0    62.0         5       1024                0
# 58         58  0.027288      3.0    63.0         5       1024                0
# 59         59  0.027713      2.0    65.0         5       1024                0

# %%
best_fitness = df_run_curves['Fitness'].min()
best_runs = df_run_curves[df_run_curves['Fitness'] == best_fitness]
best_runs
# Out:
#       Iteration      Time  Fitness  FEvals  Restarts  max_iters  \
# 1103         25  0.017518      0.0  1116.0         5       1024
# 2207         25  0.017518      0.0  1116.0        10       1024
# 3311         25  0.017518      0.0  1116.0        20       1024
# 4415         25  0.017518      0.0  1116.0        50       1024
# 5519         25  0.017518      0.0  1116.0        75       1024
# 6623         25  0.017518      0.0  1116.0       100       1024
#
#       current_restart
# 1103                2
# 2207                2
# 3311                2
# 4415                2
# 5519                2
# 6623                2

# %%
minimum_evaluations = best_runs['FEvals'].min()
best_curve_run = best_runs[best_runs['FEvals'] == minimum_evaluations]
best_curve_run
# Out:
#       Iteration      Time  Fitness  FEvals  Restarts  max_iters  \
# 1103         25  0.017518      0.0  1116.0         5       1024
# 2207         25  0.017518      0.0  1116.0        10       1024
# 3311         25  0.017518      0.0  1116.0        20       1024
# 4415         25  0.017518      0.0  1116.0        50       1024
# 5519         25  0.017518      0.0  1116.0        75       1024
# 6623         25  0.017518      0.0  1116.0       100       1024
#
#       current_restart
# 1103                2
# 2207                2
# 3311                2
# 4415                2
# 5519                2
# 6623                2

# %%
best_Restarts = best_curve_run['Restarts'].iloc()[0]

print(f'Best Restarts: {best_Restarts}')
# Out:
# Best Restarts: 5

# %%
run_stats_best_run = df_run_stats[df_run_stats['Restarts'] == best_Restarts]
run_stats_best_run
# Out:
0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
#
#     max_iters  current_restart
# 0        1024                0
# 1        1024                0
# 2        1024                0
# 3        1024                0
# 4        1024                0
# 5        1024                0
# 6        1024                0
# 7        1024                0
# 8        1024                0
# 9        1024                0
# 10       1024                0
# 11       1024                0
# 12       1024                1
# 13       1024                1
# 14       1024                1
# 15       1024                1
# 16       1024                1
# 17       1024                1
# 18       1024                1
# 19       1024                1
# 20       1024                1
# 21       1024                1
# 22       1024                1
# 23       1024                1
# 24       1024                2
# 25       1024                2
# 26       1024                2
# 27       1024                2
# 28       1024                2
# 29       1024                2
# 30       1024                2
# 31       1024                2
# 32       1024                2
# 33       1024                2
# 34       1024                2
# 35       1024                2

# %%
best_state = run_stats_best_run.tail(1)
best_state
# Out:
#     Iteration  Fitness  FEvals      Time                     State  Restarts  \
# 35       1024      0.0    1116  0.819339  [5, 2, 0, 7, 3, 1, 6, 4]         5
#
#     max_iters  current_restart
# 35       1024                2

# %%
opt_curve=df_run_curves[(df_run_curves['Restarts']==best_state['Restarts'].iloc[0]) & (df_run_curves['current_restart']==best_state['current_restart'].iloc[0])]
opt_curve
# Out:
#       Iteration      Time  Fitness  FEvals  Restarts  max_iters  \
# 1079          1  0.003988      7.0  1088.0         5       1024
# 1080          2  0.005996      7.0  1089.0         5       1024
# 1081          3  0.007562      7.0  1090.0         5       1024
# 1082          4  0.007955      7.0  1091.0         5       1024
# 1083          5  0.009531      5.0  1093.0         5       1024
# 1084          6  0.009749      5.0  1094.0         5       1024
# 1085          7  0.009963      5.0  1095.0         5       1024
# 1086          8  0.010177      5.0  1096.0         5       1024
# 1087          9  0.011833      5.0  1097.0         5       1024
# 1088         10  0.012115      5.0  1098.0         5       1024
# 1089         11  0.012331      5.0  1099.0         5       1024
# 1090         12  0.012721      4.0  1101.0         5       1024
# 1091         13  0.013111      2.0  1103.0         5       1024
# 1092         14  0.013500      2.0  1104.0         5       1024
# 1093         15  0.013890      2.0  1105.0         5       1024
# 1094         16  0.014106      2.0  1106.0         5       1024
# 1095         17  0.015722      2.0  1107.0         5       1024
# 1096         18  0.015950      2.0  1108.0         5       1024
# 1097         19  0.016176      2.0  1109.0         5       1024
# 1098         20  0.016397      2.0  1110.0         5       1024
# 1099         21  0.016620      2.0  1111.0         5       1024
# 1100         22  0.016843      2.0  1112.0         5       1024
# 1101         23  0.017067      2.0  1113.0         5       1024
# 1102         24  0.017293      2.0  1114.0         5       1024
# 1103         25  0.017518      0.0  1116.0         5       1024
#
#       current_restart
# 1079                2
# 1080                2
# 1081                2
# 1082                2
# 1083                2
# 1084                2
# 1085                2
# 1086                2
# 1087                2
# 1088                2
# 1089                2
# 1090                2
# 1091                2
# 1092                2
# 1093                2
# 1094                2
# 1095                2
# 1096                2
# 1097                2
# 1098                2
# 1099                2
# 1100                2
# 1101                2
# 1102                2
# 1103                2

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('Randomized Hill Climbing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],28-opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.legend()
plt.title('Randomized Hill Climbing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('Randomized Hill Climbing')
plt.show()

# %%
result1=best_state[['Fitness','FEvals','Time','State']]
result1['Algorithm']='Randomized Hill Climbing'

# %%
state = literal_eval(run_stats_best_run['State'].tail(1).values[0])
print(state)
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)
board
# Out:
# [5, 2, 0, 7, 3, 1, 6, 4]
# Board('5Q2/2Q5/Q7/7Q/3Q4/1Q6/6Q1/4Q3 w - - 0 1')

# %% [markdown]
# ### Algorithm 2: Simulated Annealing

# %%
# Generate a new 8-Queen problem using a fixed seed.
problem = QueensGenerator().generate(seed=123456, size=8)

#Initial State
state = [0,1,2,3,4,5,6,7]
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)

# %%
# create a runner class and solve the problem
sa = SARunner(problem=problem,
              experiment_name='queens8_sa',
              output_directory=None, # note: specify an output directory to have results saved to disk
              seed=123456,
              iteration_list=2 ** np.arange(11),
              max_attempts=500,
              temperature_list=[0.1, 0.5, 0.75, 1.0, 2.0, 5.0],
              decay_list=[mlrose_hiive.GeomDecay])

# the two data frames will contain the results
df_run_stats, df_run_curves = sa.run()

# %%
df_run_stats.iloc[:60]
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 0           0     11.0       0  0.001169  [1, 2, 2, 1, 0, 3, 7, 3]
# 1           1      9.0       2  0.003739  [1, 2, 2, 0, 0, 3, 7, 3]
# 2           2      8.0       4  0.006144  [1, 2, 2, 0, 0, 3, 7, 5]
# 3           4      8.0       7  0.008331  [1, 2, 2, 5, 0, 3, 7, 5]
# 4           8      5.0      13  0.011061  [1, 2, 7, 5, 0, 3, 5, 5]
# 5          16      4.0      24  0.014911  [1, 2, 7, 5, 3, 0, 5, 5]
# 6          32      4.0      47  0.021349  [1, 5, 7, 5, 0, 0, 3, 4]
# 7          64      1.0      86  0.032011  [1, 5, 2, 6, 3, 0, 7, 4]
# 8         128      1.0     155  0.052472  [1, 5, 2, 6, 3, 0, 4, 7]
# 9         256      1.0     295  0.101335  [1, 7, 2, 6, 3, 5, 0, 4]
# 10        512      0.0     461  0.176237  [1, 5, 0, 6, 3, 7, 2, 4]
# 11       1024      0.0     461  0.176237  [1, 5, 0, 6, 3, 7, 2, 4]
# 12          0     11.0       0  0.000403  [1, 2, 2, 1, 0, 3, 7, 3]
# 13          1      9.0       2  0.002530  [1, 2, 2, 0, 0, 3, 7, 3]
# 14          2      8.0       4  0.005108  [1, 2, 2, 0, 0, 3, 7, 5]
# 15          4      8.0       7  0.007477  [1, 2, 2, 5, 0, 3, 7, 5]
# 16          8      5.0      13  0.010425  [1, 2, 7, 5, 0, 3, 5, 5]
# 17         16      4.0      24  0.015145  [1, 2, 7, 5, 3, 0, 5, 5]
# 18         32      4.0      47  0.021754  [1, 5, 7, 5, 0, 0, 3, 4]
# 55         64      5.0     114  0.052475  [2, 0, 3, 6, 1, 2, 1, 7]
# 56        128      3.0     205  0.078403  [2, 0, 6, 3, 5, 0, 4, 3]
# 57        256      2.0     358  0.131868  [7, 1, 3, 6, 6, 4, 0, 5]
# 58        512      0.0     427  0.164522  [7, 1, 3, 0, 6, 4, 2, 5]
# 59       1024      0.0     427  0.164522  [7, 1, 3, 0, 6, 4, 2, 5]
#
#    schedule_type  schedule_init_temp  schedule_decay  schedule_min_temp  \
# 0      geometric                0.10            0.99              0.001
# 1      geometric                0.10            0.99              0.001
# 2      geometric                0.10            0.99              0.001
# 3      geometric                0.10            0.99              0.001
# 4      geometric                0.10            0.99              0.001
# 5      geometric                0.10            0.99              0.001
# 6      geometric                0.10            0.99              0.001
# 7      geometric                0.10            0.99              0.001
# 8      geometric                0.10            0.99              0.001
# 9      geometric                0.10            0.99              0.001
# 10     geometric                0.10            0.99              0.001
# 11     geometric                0.10            0.99              0.001
# 12     geometric                0.50            0.99              0.001
# 13     geometric                0.50            0.99              0.001
# 14     geometric                0.50            0.99              0.001
# 15     geometric                0.50            0.99              0.001
# 16     geometric                0.50            0.99              0.001
# 17     geometric                0.50            0.99              0.001
# 18     geometric                0.50            0.99              0.001
# 19     geometric                0.50            0.99              0.001
# 20     geometric                0.50            0.99              0.001
# 21     geometric                0.50            0.99              0.001
# 22     geometric                0.50            0.99              0.001
# 23     geometric                0.50            0.99              0.001
# 24     geometric                0.75            0.99              0.001
# 25     geometric                0.75            0.99              0.001
# 26     geometric                0.75            0.99              0.001
# 27     geometric                0.75            0.99              0.001
# 28     geometric                0.75            0.99              0.001
# 29     geometric                0.75            0.99              0.001
# 30     geometric                0.75            0.99              0.001
# 31     geometric                0.75            0.99              0.001
# 32     geometric                0.75            0.99              0.001
# 33     geometric                0.75            0.99              0.001
# 34     geometric                0.75            0.99              0.001
# 35     geometric                0.75            0.99              0.001
# 36     geometric                1.00            0.99              0.001
# 37     geometric                1.00            0.99              0.001
# 38     geometric                1.00            0.99              0.001
# 39     geometric                1.00            0.99              0.001
# 40     geometric                1.00            0.99              0.001
# 41     geometric                1.00            0.99              0.001
# 42     geometric                1.00            0.99              0.001
# 43     geometric                1.00            0.99              0.001
# 44     geometric                1.00            0.99              0.001
# 45     geometric                1.00            0.99              0.001
# 46     geometric                1.00            0.99              0.001
# 47     geometric                1.00            0.99              0.001
# 48     geometric                2.00            0.99              0.001
# 49     geometric                2.00            0.99              0.001
# 50     geometric                2.00            0.99              0.001
# 51     geometric                2.00            0.99              0.001
# 52     geometric                2.00            0.99              0.001
# 53     geometric                2.00            0.99              0.001
# 54     geometric                2.00            0.99              0.001
# 55     geometric                2.00            0.99              0.001
# 56     geometric                2.00            0.99              0.001
# 57     geometric                2.00            0.99              0.001
# 58     geometric                2.00            0.99              0.001
# 59     geometric                2.00            0.99              0.001
#
#     schedule_current_value Temperature  max_iters
# 0                 0.099999         0.1       1024
# 1                 0.099996         0.1       1024
# 2                 0.099994         0.1       1024
# 3                 0.099992         0.1       1024
# 4                 0.099989         0.1       1024
# 5                 0.099985         0.1       1024
# 6                 0.099979         0.1       1024
# 7                 0.099968         0.1       1024
# 8                 0.099947         0.1       1024
# 9                 0.099898         0.1       1024
# 10                0.099823         0.1       1024
# 11                0.099823         0.1       1024
# 12                0.499998         0.5       1024
# 13                0.499987         0.5       1024
# 14                0.499974         0.5       1024
# 15                0.499962         0.5       1024
# 16                0.499948         0.5       1024
# 17                0.499924         0.5       1024
# 18                0.499891         0.5       1024
# 19                0.499836         0.5       1024
# 20                0.499734         0.5       1024
# 21                0.499492         0.5       1024
# 22                0.499106         0.5       1024
# 23                0.499106         0.5       1024
# 24                0.749997        0.75       1024
# 25                0.749978        0.75       1024
# 26                0.749958        0.75       1024
# 27                0.749936        0.75       1024
# 28                0.749906        0.75       1024
# 29                0.749869        0.75       1024
# 30                0.749815        0.75       1024
# 31                0.749728        0.75       1024
# 32                0.749550        0.75       1024
# 33                0.749181        0.75       1024
# 34                0.748224        0.75       1024
# 35                0.745263        0.75       1024
# 36                0.999996         1.0       1024
# 37                0.999961         1.0       1024
# 38                0.999927         1.0       1024
# 39                0.999889         1.0       1024
# 40                0.999844         1.0       1024
# 41                0.999786         1.0       1024
# 42                0.999696         1.0       1024
# 43                0.999559         1.0       1024
# 44                0.999324         1.0       1024
# 45                0.998832         1.0       1024
# 46                0.997562         1.0       1024
# 47                0.997231         1.0       1024
# 48                1.999992         2.0       1024
# 49                1.999914         2.0       1024
# 50                1.999832         2.0       1024
# 51                1.999748         2.0       1024
# 52                1.999650         2.0       1024
# 53                1.999527         2.0       1024
# 54                1.999273         2.0       1024
# 55                1.998945         2.0       1024
# 56                1.998425         2.0       1024
# 57                1.997351         2.0       1024
# 58                1.996696         2.0       1024
# 59                1.996696         2.0       1024

# %%
df_run_curves
# Out:
#       Iteration      Time  Fitness  FEvals Temperature  max_iters
# 0             0  0.001169     11.0     0.0         0.1       1024
# 1             1  0.003739      9.0     2.0         0.1       1024
# 2             2  0.006144      8.0     4.0         0.1       1024
# 3             3  0.007907      8.0     5.0         0.1       1024
# 4             4  0.008331      8.0     7.0         0.1       1024
# ...         ...       ...      ...     ...         ...        ...
# 3160        420  0.009623      1.0   578.0         5.0       1024
# 3161        421  0.009839      1.0   579.0         5.0       1024
# 3162        422  0.010051      1.0   580.0         5.0       1024
# 3163        423  0.010425      1.0   581.0         5.0       1024
# 3164        424  0.012406      0.0   583.0         5.0       1024
#
# [3165 rows x 6 columns]

# %%
best_fitness = df_run_curves['Fitness'].min()
best_runs = df_run_curves[df_run_curves['Fitness'] == best_fitness]
best_runs
# Out:
#       Iteration      Time  Fitness  FEvals Temperature  max_iters
# 414         414  0.176237      0.0   461.0         0.1       1024
# 829         414  0.176237      0.0   461.0         0.5       1024
# 2416        561  0.061022      0.0   639.0         1.0       1024
# 2739        322  0.131805      0.0   427.0         2.0       1024
# 3164        424  0.012406      0.0   583.0         5.0       1024

# %%
minimum_evaluations = best_runs['FEvals'].min()
best_curve_run = best_runs[best_runs['FEvals'] == minimum_evaluations]
best_curve_run
# Out:
#       Iteration      Time  Fitness  FEvals Temperature  max_iters
# 2739        322  0.131805      0.0   427.0         2.0       1024

# %%
best_init_temperature = best_curve_run['Temperature'].iloc()[0].init_temp

print(f'Best initial temperature: {best_init_temperature}')
# Out:
# Best initial temperature: 2.0

# %%
run_stats_best_run = df_run_stats[df_run_stats['schedule_init_temp'] == best_init_temperature]
run_stats_best_run
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 48          0     11.0       0  0.000405  [1, 2, 2, 1, 0, 3, 7, 3]
# 49          1      9.0       2  0.004293  [1, 2, 2, 0, 0, 3, 7, 3]
# 50          2      8.0       4  0.008372  [1, 2, 2, 0, 0, 3, 7, 5]
# 51          4      8.0       7  0.012520  [1, 2, 2, 5, 0, 3, 7, 5]
# 52          8      7.0      14  0.017418  [1, 2, 2, 5, 0, 3, 5, 5]
# 53         16      6.0      27  0.023524  [3, 2, 3, 5, 0, 1, 5, 5]
# 54         32      4.0      57  0.036154  [3, 5, 6, 5, 5, 0, 4, 7]
# 55         64      5.0     114  0.052475  [2, 0, 3, 6, 1, 2, 1, 7]
# 56        128      3.0     205  0.078403  [2, 0, 6, 3, 5, 0, 4, 3]
# 57        256      2.0     358  0.131868  [7, 1, 3, 6, 6, 4, 0, 5]
# 58        512      0.0     427  0.164522  [7, 1, 3, 0, 6, 4, 2, 5]
# 59       1024      0.0     427  0.164522  [7, 1, 3, 0, 6, 4, 2, 5]
#
#    schedule_type  schedule_init_temp  schedule_decay  schedule_min_temp  \
# 48     geometric                 2.0            0.99              0.001
# 49     geometric                 2.0            0.99              0.001
# 50     geometric                 2.0            0.99              0.001
# 51     geometric                 2.0            0.99              0.001
# 52     geometric                 2.0            0.99              0.001
# 53     geometric                 2.0            0.99              0.001
# 54     geometric                 2.0            0.99              0.001
# 55     geometric                 2.0            0.99              0.001
# 56     geometric                 2.0            0.99              0.001
# 57     geometric                 2.0            0.99              0.001
# 58     geometric                 2.0            0.99              0.001
# 59     geometric                 2.0            0.99              0.001
#
#     schedule_current_value Temperature  max_iters
# 48                1.999992         2.0       1024
# 49                1.999914         2.0       1024
# 50                1.999832         2.0       1024
# 51                1.999748         2.0       1024
# 52                1.999650         2.0       1024
# 53                1.999527         2.0       1024
# 54                1.999273         2.0       1024
# 55                1.998945         2.0       1024
# 56                1.998425         2.0       1024
# 57                1.997351         2.0       1024
# 58                1.996696         2.0       1024
# 59                1.996696         2.0       1024

# %%
best_state = run_stats_best_run.tail(1)
best_state
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 59       1024      0.0     427  0.164522  [7, 1, 3, 0, 6, 4, 2, 5]
#
#    schedule_type  schedule_init_temp  schedule_decay  schedule_min_temp  \
# 59     geometric                 2.0            0.99              0.001
#
#     schedule_current_value Temperature  max_iters
# 59                1.996696         2.0       1024

# %%
opt_curve=df_run_curves[(df_run_curves['Temperature']==best_state['Temperature'].iloc[0])]
opt_curve
# Out:
#       Iteration      Time  Fitness  FEvals Temperature  max_iters
# 2417          0  0.001169     11.0     0.0         2.0       1024
# 2418          1  0.003739      9.0     2.0         2.0       1024
# 2419          2  0.006144      8.0     4.0         2.0       1024
# 2420          3  0.007907      8.0     5.0         2.0       1024
# 2421          4  0.008331      8.0     7.0         2.0       1024
# ...         ...       ...      ...     ...         ...        ...
# 2735        318  0.130042      1.0   422.0         2.0       1024
# 2736        319  0.130482      1.0   423.0         2.0       1024
# 2737        320  0.130921      1.0   424.0         2.0       1024
# 2738        321  0.131363      1.0   425.0         2.0       1024
# 2739        322  0.131805      0.0   427.0         2.0       1024
#
# [323 rows x 6 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('Simulated Annealing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],28-opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.legend()
plt.title('Simulated Annealing')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('Simulated Annealing')
plt.show()

# %%
result2=best_state[['Fitness','FEvals','Time','State']]
result2['Algorithm']='Simulated Annealing'

# %%
state = literal_eval(run_stats_best_run['State'].tail(1).values[0])
print(state)
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)
board
# Out:
# [7, 1, 3, 0, 6, 4, 2, 5]
# Board('7Q/1Q6/3Q4/Q7/6Q1/4Q3/2Q5/5Q2 w - - 0 1')

# %% [markdown]
# ### Algorithm 3: Generic Algorithm

# %%
# Generate a new 8-Queen problem using a fixed seed.
problem = QueensGenerator().generate(seed=123456, size=8)

#Initial State
state = [0,1,2,3,4,5,6,7]
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)

# %%
ga = GARunner(problem=problem,
                  experiment_name='queen8_ga',
                  output_directory=None,
                  seed=1234,
                  iteration_list=2 ** np.arange(11),
                  max_attempts=500,
                  population_sizes=[10, 20, 50, 100, 150],
                  mutation_rates=[0.1, 0.3, 0.5, 0.7])
                  
# the two data frames will contain the results
df_run_stats, df_run_curves = ga.run()

# %%
df_run_stats.iloc[:60]
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 0           0      9.0      10  0.003925  [7, 3, 6, 5, 4, 4, 0, 1]
# 1           1      5.0      22  0.008109  [6, 3, 7, 4, 2, 3, 6, 4]
# 2           2      3.0      34  0.011970  [6, 3, 7, 1, 3, 0, 6, 4]
# 3           4      3.0      56  0.018040  [6, 3, 7, 1, 3, 0, 6, 4]
# 4           8      2.0     101  0.029180  [7, 3, 7, 7, 2, 0, 6, 1]
# 5          16      2.0     189  0.050002  [7, 3, 7, 7, 2, 0, 6, 1]
# 42         32      1.0     367  0.094757  [2, 5, 7, 4, 0, 3, 6, 6]
# 43         64      1.0     719  0.174088  [2, 5, 7, 4, 0, 3, 6, 6]
# 44        128      1.0    1423  0.335452  [2, 5, 7, 4, 0, 3, 6, 6]
# 45        256      0.0    2370  0.551163  [2, 5, 3, 1, 7, 4, 6, 0]
# 46        512      0.0    2370  0.551163  [2, 5, 3, 1, 7, 4, 6, 0]
# 47       1024      0.0    2370  0.551163  [2, 5, 3, 1, 7, 4, 6, 0]
# 48          0      9.0      20  0.004299  [7, 3, 6, 5, 4, 4, 0, 1]
# 49          1      3.0      42  0.011575  [1, 7, 3, 6, 0, 5, 1, 5]
# 50          2      3.0      63  0.018640  [1, 7, 3, 6, 0, 5, 1, 5]
# 51          4      3.0     105  0.030200  [1, 7, 3, 6, 0, 5, 1, 5]
# 52          8      2.0     190  0.050751  [5, 7, 1, 7, 0, 6, 3, 2]
# 53         16      1.0     359  0.089145  [5, 7, 1, 4, 0, 3, 6, 2]
# 54         32      1.0     695  0.166055  [5, 7, 1, 4, 0, 3, 6, 2]
# 55         64      1.0    1367  0.312577  [5, 7, 1, 4, 0, 3, 6, 2]
# 56        128      1.0    2711  0.596142  [5, 7, 1, 4, 0, 3, 6, 2]
# 57        256      1.0    5399  1.190745  [5, 7, 1, 4, 0, 3, 6, 2]
# 58        512      1.0   10775  2.388718  [5, 7, 1, 4, 0, 3, 6, 2]
# 59       1024      1.0   10859  2.411773  [5, 7, 1, 4, 0, 3, 6, 2]
#
#     Population Size  Mutation Rate  max_iters
# 0                10            0.1       1024
# 1                10            0.1       1024
# 2                10            0.1       1024
# 3                10            0.1       1024
# 4                10            0.1       1024
# 5                10            0.1       1024
# 6                10            0.1       1024
# 7                10            0.1       1024
# 8                10            0.1       1024
# 9                10            0.1       1024
# 10               10            0.1       1024
# 11               10            0.1       1024
# 12               10            0.3       1024
# 13               10            0.3       1024
# 14               10            0.3       1024
# 15               10            0.3       1024
# 16               10            0.3       1024
# 17               10            0.3       1024
# 18               10            0.3       1024
# 19               10            0.3       1024
# 20               10            0.3       1024
# 21               10            0.3       1024
# 22               10            0.3       1024
# 23               10            0.3       1024
# 24               10            0.5       1024
# 25               10            0.5       1024
# 26               10            0.5       1024
# 27               10            0.5       1024
# 28               10            0.5       1024
# 29               10            0.5       1024
# 30               10            0.5       1024
# 31               10            0.5       1024
# 32               10            0.5       1024
# 33               10            0.5       1024
# 34               10            0.5       1024
# 35               10            0.5       1024
# 36               10            0.7       1024
# 37               10            0.7       1024
# 38               10            0.7       1024
# 39               10            0.7       1024
# 40               10            0.7       1024
# 41               10            0.7       1024
# 42               10            0.7       1024
# 43               10            0.7       1024
# 44               10            0.7       1024
# 45               10            0.7       1024
# 46               10            0.7       1024
# 47               10            0.7       1024
# 48               20            0.1       1024
# 49               20            0.1       1024
# 50               20            0.1       1024
# 51               20            0.1       1024
# 52               20            0.1       1024
# 53               20            0.1       1024
# 54               20            0.1       1024
# 55               20            0.1       1024
# 56               20            0.1       1024
# 57               20            0.1       1024
# 58               20            0.1       1024
# 59               20            0.1       1024

# %%
df_run_curves
# Out:
#       Iteration      Time  Fitness  FEvals  Population Size  Mutation Rate  \
# 0             0  0.003925      9.0    10.0               10            0.1
# 1             1  0.008109      5.0    22.0               10            0.1
# 2             2  0.011970      3.0    34.0               10            0.1
# 3             3  0.015643      3.0    45.0               10            0.1
# 4             4  0.018040      3.0    56.0               10            0.1
# ...         ...       ...      ...     ...              ...            ...
# 4796         26  0.075425      1.0  4079.0              150            0.7
# 4797         27  0.077814      1.0  4230.0              150            0.7
# 4798         28  0.080186      1.0  4381.0              150            0.7
# 4799         29  0.082595      1.0  4532.0              150            0.7
# 4800         30  0.084979      0.0  4684.0              150            0.7
#
#       max_iters
# 0          1024
# 1          1024
# 2          1024
# 3          1024
# 4          1024
# ...         ...
# 4796       1024
# 4797       1024
# 4798       1024
# 4799       1024
# 4800       1024
#
# [4801 rows x 7 columns]

# %%
best_fitness = df_run_curves['Fitness'].min()
best_runs = df_run_curves[df_run_curves['Fitness'] == best_fitness]
best_runs
# Out:
#       Iteration      Time  Fitness   FEvals  Population Size  Mutation Rate  \
# 397         397  1.028451      0.0   4382.0               10            0.1
# 1097         35  0.098565      0.0    400.0               10            0.5
# 1312        214  0.548502      0.0   2370.0               10            0.7
# 2551         90  0.239017      0.0   1915.0               20            0.5
# 3085         13  0.042564      0.0    716.0               50            0.1
# 3410        324  0.834989      0.0  16578.0               50            0.3
# 3431         20  0.060988      0.0   1073.0               50            0.5
# 3498         66  0.176075      0.0   3420.0               50            0.7
# 4051         37  0.103457      0.0   3841.0              100            0.3
# 4188        136  0.355707      0.0  13840.0              100            0.5
# 4224         35  0.098565      0.0   3638.0              100            0.7
# 4749         17  0.053732      0.0   2721.0              150            0.3
# 4769         19  0.058562      0.0   3023.0              150            0.5
# 4800         30  0.084979      0.0   4684.0              150            0.7
#
#       max_iters
# 397        1024
# 1097       1024
# 1312       1024
# 2551       1024
# 3085       1024
# 3410       1024
# 3431       1024
# 3498       1024
# 4051       1024
# 4188       1024
# 4224       1024
# 4749       1024
# 4769       1024
# 4800       1024

# %%
minimum_evaluations = best_runs['FEvals'].min()
best_curve_run = best_runs[best_runs['FEvals'] == minimum_evaluations]
best_curve_run
# Out:
#       Iteration      Time  Fitness  FEvals  Population Size  Mutation Rate  \
# 1097         35  0.098565      0.0   400.0               10            0.5
#
#       max_iters
# 1097       1024

# %%
best_Population_Size = best_curve_run['Population Size'].iloc()[0]
best_Mutation_Rate = best_curve_run['Mutation Rate'].iloc()[0]
print(f'Best Population: {best_Population_Size}')
print(f'Best Mutation Rate: {best_Mutation_Rate}')
# Out:
# Best Population: 10
# Best Mutation Rate: 0.5

# %%
run_stats_best_run = df_run_stats[(df_run_stats['Population Size'] == best_Population_Size) & (df_run_stats['Mutation Rate'] == best_Mutation_Rate)]
run_stats_best_run
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 24          0      9.0      10  0.002299  [7, 3, 6, 5, 4, 4, 0, 1]
# 25          1      5.0      22  0.007514  [6, 3, 7, 4, 3, 3, 6, 4]
# 26          2      5.0      33  0.012525  [6, 3, 7, 4, 3, 3, 6, 4]
# 27          4      3.0      56  0.020249  [5, 0, 1, 7, 0, 3, 7, 2]
# 28          8      2.0     101  0.032214  [5, 0, 1, 7, 0, 3, 6, 2]
# 29         16      1.0     190  0.053670  [5, 0, 4, 7, 0, 3, 6, 2]
# 30         32      1.0     366  0.094676  [5, 0, 4, 7, 0, 3, 6, 2]
# 31         64      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
# 32        128      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
# 33        256      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
# 34        512      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
# 35       1024      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
#
#     Population Size  Mutation Rate  max_iters
# 24               10            0.5       1024
# 25               10            0.5       1024
# 26               10            0.5       1024
# 27               10            0.5       1024
# 28               10            0.5       1024
# 29               10            0.5       1024
# 30               10            0.5       1024
# 31               10            0.5       1024
# 32               10            0.5       1024
# 33               10            0.5       1024
# 34               10            0.5       1024
# 35               10            0.5       1024

# %%
best_state = run_stats_best_run.tail(1)
best_state
# Out:
#     Iteration  Fitness  FEvals      Time                     State  \
# 35       1024      0.0     400  0.104406  [5, 2, 4, 7, 0, 3, 1, 6]
#
#     Population Size  Mutation Rate  max_iters
# 35               10            0.5       1024

# %%
opt_curve=df_run_curves[(df_run_curves['Population Size']==best_state['Population Size'].iloc[0]) & (df_run_curves['Mutation Rate']==best_state['Mutation Rate'].iloc[0])]
opt_curve
# Out:
#       Iteration      Time  Fitness  FEvals  Population Size  Mutation Rate  \
# 1062          0  0.003925      9.0    10.0               10            0.5
# 1063          1  0.008109      5.0    22.0               10            0.5
# 1064          2  0.011970      5.0    33.0               10            0.5
# 1065          3  0.015643      5.0    44.0               10            0.5
# 1066          4  0.018040      3.0    56.0               10            0.5
# 1067          5  0.021956      3.0    67.0               10            0.5
# 1068          6  0.024387      2.0    79.0               10            0.5
# 1069          7  0.026787      2.0    90.0               10            0.5
# 1070          8  0.029180      2.0   101.0               10            0.5
# 1071          9  0.032883      2.0   112.0               10            0.5
# 1072         10  0.035293      2.0   123.0               10            0.5
# 1073         11  0.037701      2.0   134.0               10            0.5
# 1074         12  0.040122      1.0   146.0               10            0.5
# 1075         13  0.042564      1.0   157.0               10            0.5
# 1076         14  0.045173      1.0   168.0               10            0.5
# 1077         15  0.047589      1.0   179.0               10            0.5
# 1078         16  0.050002      1.0   190.0               10            0.5
# 1079         17  0.053732      1.0   201.0               10            0.5
# 1080         18  0.056158      1.0   212.0               10            0.5
# 1081         19  0.058562      1.0   223.0               10            0.5
# 1082         20  0.060988      1.0   234.0               10            0.5
# 1083         21  0.063391      1.0   245.0               10            0.5
# 1084         22  0.065816      1.0   256.0               10            0.5
# 1085         23  0.068205      1.0   267.0               10            0.5
# 1086         24  0.070606      1.0   278.0               10            0.5
# 1087         25  0.073021      1.0   289.0               10            0.5
# 1088         26  0.075425      1.0   300.0               10            0.5
# 1089         27  0.077814      1.0   311.0               10            0.5
# 1090         28  0.080186      1.0   322.0               10            0.5
# 1091         29  0.082595      1.0   333.0               10            0.5
# 1092         30  0.084979      1.0   344.0               10            0.5
# 1093         31  0.087376      1.0   355.0               10            0.5
# 1094         32  0.089761      1.0   366.0               10            0.5
# 1095         33  0.093537      1.0   377.0               10            0.5
# 1096         34  0.096150      1.0   388.0               10            0.5
# 1097         35  0.098565      0.0   400.0               10            0.5
#
#       max_iters
# 1062       1024
# 1063       1024
# 1064       1024
# 1065       1024
# 1066       1024
# 1067       1024
# 1068       1024
# 1069       1024
# 1070       1024
# 1071       1024
# 1072       1024
# 1073       1024
# 1074       1024
# 1075       1024
# 1076       1024
# 1077       1024
# 1078       1024
# 1079       1024
# 1080       1024
# 1081       1024
# 1082       1024
# 1083       1024
# 1084       1024
# 1085       1024
# 1086       1024
# 1087       1024
# 1088       1024
# 1089       1024
# 1090       1024
# 1091       1024
# 1092       1024
# 1093       1024
# 1094       1024
# 1095       1024
# 1096       1024
# 1097       1024

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('Generic Algorithm')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],28-opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.legend()
plt.title('Generic Algorithm')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('Generic Algorithm')
plt.show()

# %%
result3=best_state[['Fitness','FEvals','Time','State']]
result3['Algorithm']='Genetic Algorithm'

# %%
state = literal_eval(run_stats_best_run['State'].tail(1).values[0])
print(state)
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)
board
# Out:
# [5, 2, 4, 7, 0, 3, 1, 6]
# Board('5Q2/2Q5/4Q3/7Q/Q7/3Q4/1Q6/6Q1 w - - 0 1')

# %% [markdown]
# ### Algorithm 4: MIMIC

# %%
# Generate a new 8-Queen problem using a fixed seed.
problem = QueensGenerator().generate(seed=123456, size=8)

#Initial State
state = [0,1,2,3,4,5,6,7]
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)

# %%
mmc = MIMICRunner(problem=problem,
                      experiment_name='queen8_mimic',
                      output_directory=None,
                      seed=12345,
                      iteration_list=2 ** np.arange(11),
                      max_attempts=500,
                      population_sizes=[150, 200],
                      keep_percent_list=[0.25, 0.5, 0.75])
                      
# the two data frames will contain the results
df_run_stats, df_run_curves = mmc.run()

# %%
df_run_stats.iloc[:60]
# Out:
# 51  [7.0, 1.0, 5.0, 0.0, 2.0, 4.0, 6.0, 3.0]           False              200
# 52  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 53  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 54  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 55  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 56  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 57  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 58  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
# 59  [3.0, 6.0, 0.0, 7.0, 5.0, 0.0, 2.0, 4.0]           False              200
#
#     Keep Percent  max_iters
# 0           0.25       1024
# 1           0.25       1024
# 2           0.25       1024
# 3           0.25       1024
# 4           0.25       1024
# 5           0.25       1024
# 6           0.25       1024
# 7           0.25       1024
# 8           0.25       1024
# 9           0.25       1024
# 10          0.25       1024
# 11          0.25       1024
# 12          0.50       1024
# 13          0.50       1024
# 14          0.50       1024
# 15          0.50       1024
# 16          0.50       1024
# 17          0.50       1024
# 18          0.50       1024
# 19          0.50       1024
# 20          0.50       1024
# 21          0.50       1024
# 22          0.50       1024
# 23          0.50       1024
# 24          0.75       1024
# 25          0.75       1024
# 26          0.75       1024
# 27          0.75       1024
# 28          0.75       1024
# 29          0.75       1024
# 30          0.75       1024
# 31          0.75       1024
# 32          0.75       1024
# 33          0.75       1024
# 34          0.75       1024
# 35          0.75       1024
# 36          0.25       1024
# 37          0.25       1024
# 38          0.25       1024
# 39          0.25       1024
# 40          0.25       1024
# 41          0.25       1024
# 42          0.25       1024
# 43          0.25       1024
# 44          0.25       1024
# 45          0.25       1024
# 46          0.25       1024
# 47          0.25       1024
# 48          0.50       1024
# 49          0.50       1024
# 50          0.50       1024
# 51          0.50       1024
# 52          0.50       1024
# 53          0.50       1024
# 54          0.50       1024
# 55          0.50       1024
# 56          0.50       1024
# 57          0.50       1024
# 58          0.50       1024
# 59          0.50       1024

# %%
df_run_curves
# Out:
#       Iteration       Time  Fitness    FEvals  use_fast_mimic  \
# 0             0   0.029641      5.0     150.0           False
# 1             1   0.083983      1.0     302.0           False
# 2             2   0.139085      1.0     453.0           False
# 3             3   0.191671      1.0     604.0           False
# 4             4   0.242127      1.0     755.0           False
# ...         ...        ...      ...       ...             ...
# 3022        500  24.228853      1.0  100703.0           False
# 3023        501  24.276299      1.0  100904.0           False
# 3024        502   0.026656      1.0  101105.0           False
# 3025        503   0.076753      1.0  101306.0           False
# 3026        504   0.130712      1.0  101507.0           False
#
#       Population Size  Keep Percent  max_iters
# 0                 150          0.25       1024
# 1                 150          0.25       1024
# 2                 150          0.25       1024
# 3                 150          0.25       1024
# 4                 150          0.25       1024
# ...               ...           ...        ...
# 3022              200          0.75       1024
# 3023              200          0.75       1024
# 3024              200          0.75       1024
# 3025              200          0.75       1024
# 3026              200          0.75       1024
#
# [3027 rows x 8 columns]

# %%
best_fitness = df_run_curves['Fitness'].min()
best_runs = df_run_curves[df_run_curves['Fitness'] == best_fitness]
best_runs
# Out:
#       Iteration       Time  Fitness    FEvals  use_fast_mimic  \
# 1             1   0.083983      1.0     302.0           False
# 2             2   0.139085      1.0     453.0           False
# 3             3   0.191671      1.0     604.0           False
# 4             4   0.242127      1.0     755.0           False
# 5             5   0.294076      1.0     906.0           False
# ...         ...        ...      ...       ...             ...
# 3022        500  24.228853      1.0  100703.0           False
# 3023        501  24.276299      1.0  100904.0           False
# 3024        502   0.026656      1.0  101105.0           False
# 3025        503   0.076753      1.0  101306.0           False
# 3026        504   0.130712      1.0  101507.0           False
#
#       Population Size  Keep Percent  max_iters
# 1                 150          0.25       1024
# 2                 150          0.25       1024
# 3                 150          0.25       1024
# 4                 150          0.25       1024
# 5                 150          0.25       1024
# ...               ...           ...        ...
# 3022              200          0.75       1024
# 3023              200          0.75       1024
# 3024              200          0.75       1024
# 3025              200          0.75       1024
# 3026              200          0.75       1024
#
# [2004 rows x 8 columns]

# %%
minimum_evaluations = best_runs['FEvals'].min()
best_curve_run = best_runs[best_runs['FEvals'] == minimum_evaluations]
best_curve_run
# Out:
#    Iteration      Time  Fitness  FEvals  use_fast_mimic  Population Size  \
# 1          1  0.083983      1.0   302.0           False              150
#
#    Keep Percent  max_iters
# 1          0.25       1024

# %%
best_Keep_Percent = best_curve_run['Keep Percent'].iloc()[0]
best_Population_Size = best_curve_run['Population Size'].iloc()[0]
print(f'Best Percent: {best_Keep_Percent}')
print(f'Best Population Size: {best_Population_Size}')
# Out:
# Best Percent: 0.25
# Best Population Size: 150

# %%
run_stats_best_run = df_run_stats[(df_run_stats['Keep Percent'] == best_Keep_Percent) & (df_run_stats['Population Size']==best_Population_Size)]
run_stats_best_run
# Out:
#     Iteration  Fitness  FEvals       Time  \
# 0           0      5.0     150   0.029641
# 1           1      1.0     302   0.083983
# 2           2      1.0     453   0.139085
# 3           4      1.0     755   0.242127
# 4           8      1.0    1359   0.438445
# 5          16      1.0    2567   0.835138
# 6          32      1.0    4983   1.627820
# 7          64      1.0    9815   3.202659
# 8         128      1.0   19479   6.334970
# 9         256      1.0   38807  12.532158
# 10        512      1.0   75802  24.276299
# 11       1024      1.0   75802  24.276299
#
#                                        State  use_fast_mimic  Population Size  \
# 0                   [2, 5, 5, 1, 4, 1, 6, 6]           False              150
# 1   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 2   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 3   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 4   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 5   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 6   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 7   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 8   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 9   [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 10  [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
# 11  [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
#
#     Keep Percent  max_iters
# 0           0.25       1024
# 1           0.25       1024
# 2           0.25       1024
# 3           0.25       1024
# 4           0.25       1024
# 5           0.25       1024
# 6           0.25       1024
# 7           0.25       1024
# 8           0.25       1024
# 9           0.25       1024
# 10          0.25       1024
# 11          0.25       1024

# %%
best_state = run_stats_best_run.tail(1)
best_state
# Out:
#     Iteration  Fitness  FEvals       Time  \
# 11       1024      1.0   75802  24.276299
#
#                                        State  use_fast_mimic  Population Size  \
# 11  [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]           False              150
#
#     Keep Percent  max_iters
# 11          0.25       1024

# %%
opt_curve=df_run_curves[(df_run_curves['Keep Percent']==best_state['Keep Percent'].iloc[0]) & (df_run_curves['Population Size']==best_state['Population Size'].iloc[0])]
opt_curve
# Out:
#      Iteration       Time  Fitness   FEvals  use_fast_mimic  Population Size  \
# 0            0   0.029641      5.0    150.0           False              150
# 1            1   0.083983      1.0    302.0           False              150
# 2            2   0.139085      1.0    453.0           False              150
# 3            3   0.191671      1.0    604.0           False              150
# 4            4   0.242127      1.0    755.0           False              150
# ..         ...        ...      ...      ...             ...              ...
# 497        497  24.086509      1.0  75198.0           False              150
# 498        498  24.133995      1.0  75349.0           False              150
# 499        499  24.181350      1.0  75500.0           False              150
# 500        500  24.228853      1.0  75651.0           False              150
# 501        501  24.276299      1.0  75802.0           False              150
#
#      Keep Percent  max_iters
# 0            0.25       1024
# 1            0.25       1024
# 2            0.25       1024
# 3            0.25       1024
# 4            0.25       1024
# ..            ...        ...
# 497          0.25       1024
# 498          0.25       1024
# 499          0.25       1024
# 500          0.25       1024
# 501          0.25       1024
#
# [502 rows x 8 columns]

# %%
plt.plot(opt_curve['Iteration'],opt_curve['Time'],label='Time')
plt.xlabel('Iteration')
plt.ylabel('Time')
plt.legend()
plt.title('MIMIC')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],28-opt_curve['Fitness'],label='Fitness')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim([0,15])
plt.legend()
plt.title('MIMIC')
plt.show()

# %%
plt.plot(opt_curve['Iteration'],opt_curve['FEvals'],label='FEvals')
plt.xlabel('Iteration')
plt.ylabel('FEvals')
plt.legend()
plt.title('MIMIC')
plt.show()

# %%
result4=best_state[['Fitness','FEvals','Time','State']]
result4['Algorithm']='MIMIC'

# %%
state = [int(i) for i in literal_eval(run_stats_best_run['State'].tail(1).values[0])]
print(state)
board_layout = '/'.join([''.join(([str(s)] if s > 0 else []) + ['Q'] + ([str((7-s))] if s < 7 else [])) for s in state])
board = chess.Board(board_layout)
board
# Out:
# [7, 4, 1, 3, 0, 6, 3, 5]
# Board('7Q/4Q3/1Q6/3Q4/Q7/6Q1/3Q4/5Q2 w - - 0 1')

# %% [markdown]
# ### Algorithm Comparison

# %%
results=pd.concat([result1,result2,result3,result4])

# %%
results['Fitness']=28-results['Fitness']

# %%
results
# Out:
#     Fitness  FEvals       Time                                     State  \
# 35     28.0    1116   0.819339                  [5, 2, 0, 7, 3, 1, 6, 4]
# 59     28.0     427   0.164522                  [7, 1, 3, 0, 6, 4, 2, 5]
# 35     28.0     400   0.104406                  [5, 2, 4, 7, 0, 3, 1, 6]
# 11     27.0   75802  24.276299  [7.0, 4.0, 1.0, 3.0, 0.0, 6.0, 3.0, 5.0]
#
#                    Algorithm
# 35  Randomized Hill Climbing
# 59       Simulated Annealing
# 35         Genetic Algorithm
# 11                     MIMIC
