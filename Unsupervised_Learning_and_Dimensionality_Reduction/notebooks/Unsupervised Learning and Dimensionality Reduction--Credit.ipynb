# %%
import numpy as np
import sklearn
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('figure', figsize=[10,5])
from sklearn import preprocessing
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
#from time import clock
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from collections import defaultdict, Counter
# from helpers import cluster_acc, myGMM,nn_arch,nn_reg
from sklearn.metrics import adjusted_mutual_info_score
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
import sys
from sklearn.metrics import accuracy_score, homogeneity_score

# %%
credit = pd.read_csv('crx.data', names=['Male','Age','Debt','YearsEmployed','PriorDefault','Employed','CreditScore','DriversLicense','Income','Approved'],
                  usecols=[0,1,2,7,8,9,10,11,14,15])

credit=credit.replace('t',1)
credit=credit.replace('f',0)
credit=credit.replace('+',1)
credit=credit.replace('-',0)
credit=credit.replace('b',1)
credit=credit.replace('a',0)
credit=credit.replace('?', np.nan)

credit=credit[credit.isnull().any(axis=1)==False]

credit['Age']=credit['Age'].astype('float64')
credit['Income']=credit['Income'].astype('int64')

# %%
credit
# Out:
#      Male    Age    Debt  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 0     1.0  30.83   0.000           1.25             1         1            1
# 1     0.0  58.67   4.460           3.04             1         1            6
# 2     0.0  24.50   0.500           1.50             1         0            0
# 3     1.0  27.83   1.540           3.75             1         1            5
# 4     1.0  20.17   5.625           1.71             1         0            0
# ..    ...    ...     ...            ...           ...       ...          ...
# 685   1.0  21.08  10.085           1.25             0         0            0
# 686   0.0  22.67   0.750           2.00             0         1            2
# 687   0.0  25.25  13.500           2.00             0         1            1
# 688   1.0  17.92   0.205           0.04             0         0            0
# 689   1.0  35.00   3.375           8.29             0         0            0
#
#      DriversLicense  Income  Approved
# 0                 0       0         1
# 1                 0     560         1
# 2                 0     824         1
# 3                 1       3         1
# 4                 0       0         1
# ..              ...     ...       ...
# 685               0       0         0
# 686               1     394         0
# 687               1       1         0
# 688               0     750         0
# 689               1       0         0
#
# [666 rows x 10 columns]

# %%
credit.to_csv('credit_a3.csv',index=False)

# %%
X = credit.loc[:, credit.columns != 'Approved']
y = credit.loc[:, credit.columns == 'Approved']

# %%
X
# Out:
#      Male    Age    Debt  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 0     1.0  30.83   0.000           1.25             1         1            1
# 1     0.0  58.67   4.460           3.04             1         1            6
# 2     0.0  24.50   0.500           1.50             1         0            0
# 3     1.0  27.83   1.540           3.75             1         1            5
# 4     1.0  20.17   5.625           1.71             1         0            0
# ..    ...    ...     ...            ...           ...       ...          ...
# 685   1.0  21.08  10.085           1.25             0         0            0
# 686   0.0  22.67   0.750           2.00             0         1            2
# 687   0.0  25.25  13.500           2.00             0         1            1
# 688   1.0  17.92   0.205           0.04             0         0            0
# 689   1.0  35.00   3.375           8.29             0         0            0
#
#      DriversLicense  Income
# 0                 0       0
# 1                 0     560
# 2                 0     824
# 3                 1       3
# 4                 0       0
# ..              ...     ...
# 685               0       0
# 686               1     394
# 687               1       1
# 688               0     750
# 689               1       0
#
# [666 rows x 9 columns]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X=min_max_scaler.fit_transform(X)

# %%
X
# Out:
# array([[1.00000000e+00, 2.56842105e-01, 0.00000000e+00, ...,
#         1.49253731e-02, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.75488722e-01, 1.59285714e-01, ...,
#         8.95522388e-02, 0.00000000e+00, 5.60000000e-03],
#        [0.00000000e+00, 1.61654135e-01, 1.78571429e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 8.24000000e-03],
#        ...,
#        [0.00000000e+00, 1.72932331e-01, 4.82142857e-01, ...,
#         1.49253731e-02, 1.00000000e+00, 1.00000000e-05],
#        [1.00000000e+00, 6.27067669e-02, 7.32142857e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 7.50000000e-03],
#        [1.00000000e+00, 3.19548872e-01, 1.20535714e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

# %%
y
# Out:
#      Approved
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 685         0
# 686         0
# 687         0
# 688         0
# 689         0
#
# [666 rows x 1 columns]

# %% [markdown]
# ### K-Means

# %%
sse = {}
for cluster in list(range(2,31)):
    kmeans = KMeans(n_clusters=cluster, max_iter=1000, random_state=44).fit(X)
    sse[cluster] = kmeans.inertia_
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(n_clusters=2, n_init=50, max_iter=1000, random_state=44).fit(X)
accuracy_score((1-kmeans.labels_), y)
# Out:
# 0.14264264264264265

# %%
kmeans = KMeans(n_clusters=2, n_init=50, max_iter=1000, random_state=44).fit(X)
adjusted_mutual_info_score((1-kmeans.labels_), y.values.reshape(666,))
# Out:
# 0.4328238501782745

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

silh = {}
homog = {}
for cluster in range(2, 31):
    kmeans = KMeans(n_clusters=cluster, n_init=50, max_iter=1000, random_state=44).fit(X)
    label = kmeans.labels_
    #print(label)
    sil_coeff = silhouette_score(X, label, metric='euclidean')
    homog_score = homogeneity_score(y.values.reshape(666,), label)
    silh[cluster] = sil_coeff
    homog[cluster] = homog_score
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
plt.figure()
plt.plot(list(silh.keys()), list(silh.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.2960722269244721
# For n_clusters=2, The homogeneity_score is 0.43423982721363547
# For n_clusters=3, The Silhouette Coefficient is 0.3042633912189627
# For n_clusters=3, The homogeneity_score is 0.3403594727006004
# For n_clusters=4, The Silhouette Coefficient is 0.343136018705857
# For n_clusters=4, The homogeneity_score is 0.43569954677695977
# For n_clusters=5, The Silhouette Coefficient is 0.375510838648283
# For n_clusters=5, The homogeneity_score is 0.3648009616441264
# For n_clusters=6, The Silhouette Coefficient is 0.4101360679647468
# For n_clusters=6, The homogeneity_score is 0.4447044731699588
# For n_clusters=7, The Silhouette Coefficient is 0.4335055135112571
# For n_clusters=7, The homogeneity_score is 0.2905475870887128
# For n_clusters=8, The Silhouette Coefficient is 0.4803811585565731
# For n_clusters=8, The homogeneity_score is 0.4087017097631725
# For n_clusters=9, The Silhouette Coefficient is 0.5164061288364039
# For n_clusters=9, The homogeneity_score is 0.3284415185049578
# For n_clusters=10, The Silhouette Coefficient is 0.5475881466092904
# For n_clusters=10, The homogeneity_score is 0.4537314636062405
# For n_clusters=11, The Silhouette Coefficient is 0.5827512972554221
# For n_clusters=11, The homogeneity_score is 0.4382504131909058
# For n_clusters=12, The Silhouette Coefficient is 0.6094991324668935
# For n_clusters=12, The homogeneity_score is 0.49253642872090614
# For n_clusters=13, The Silhouette Coefficient is 0.6349251199396697
# For n_clusters=13, The homogeneity_score is 0.49571010587178865
# For n_clusters=14, The Silhouette Coefficient is 0.654368019341095
# For n_clusters=14, The homogeneity_score is 0.4971720749228937
# For n_clusters=15, The Silhouette Coefficient is 0.672896024524688
# For n_clusters=15, The homogeneity_score is 0.49795391640578057
# For n_clusters=16, The Silhouette Coefficient is 0.6868055061474925
# For n_clusters=16, The homogeneity_score is 0.49795391640578046
# For n_clusters=17, The Silhouette Coefficient is 0.6693539474374313
# For n_clusters=17, The homogeneity_score is 0.49868069504118767
# For n_clusters=18, The Silhouette Coefficient is 0.6493081138683617
# For n_clusters=18, The homogeneity_score is 0.5005044110008919
# For n_clusters=19, The Silhouette Coefficient is 0.6436151380093854
# For n_clusters=19, The homogeneity_score is 0.5019861643171248
# For n_clusters=20, The Silhouette Coefficient is 0.5863610494822645
# For n_clusters=20, The homogeneity_score is 0.5053981292358916
# For n_clusters=21, The Silhouette Coefficient is 0.6066992920390541
# For n_clusters=21, The homogeneity_score is 0.5069018612363344
# For n_clusters=22, The Silhouette Coefficient is 0.5526280023639485
# For n_clusters=22, The homogeneity_score is 0.5063323321722611
# For n_clusters=23, The Silhouette Coefficient is 0.5628871892551247
# For n_clusters=23, The homogeneity_score is 0.5154390609503674
# For n_clusters=24, The Silhouette Coefficient is 0.5025629467327795
# For n_clusters=24, The homogeneity_score is 0.5054210480244752
# For n_clusters=25, The Silhouette Coefficient is 0.5000917334229389
# For n_clusters=25, The homogeneity_score is 0.5059161316007134
# For n_clusters=26, The Silhouette Coefficient is 0.5141315821142491
# For n_clusters=26, The homogeneity_score is 0.5111599268960137
# For n_clusters=27, The Silhouette Coefficient is 0.5112861786142101
# For n_clusters=27, The homogeneity_score is 0.5154875817364802
# For n_clusters=28, The Silhouette Coefficient is 0.4973028947080626
# For n_clusters=28, The homogeneity_score is 0.5126056945619917
# For n_clusters=29, The Silhouette Coefficient is 0.49624141258905924
# For n_clusters=29, The homogeneity_score is 0.512762447597084
# For n_clusters=30, The Silhouette Coefficient is 0.4834913523379427
# For n_clusters=30, The homogeneity_score is 0.5135381425245964

# %%
plt.figure()
plt.plot(list(silh.keys()), list(silh.values()), 'r', label="Silhouette")
plt.plot(list(homog.keys()), list(homog.values()), 'g', label="Homogeneity")
plt.legend()
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
# Out:
# Text(0, 0.5, 'Silhouette Coefficient')

# %% [markdown]
# ### Expectation Maximization

# %%
silh_EM = {}
homog_EM = {}
log_likelihood_EM = {}
for cluster in range(2, 31):
    gmm = GaussianMixture(n_components=cluster, max_iter=100, random_state=44, 
                          n_init=5).fit(X)
    label = gmm.predict(X)
    sil_coeff = silhouette_score(X, label, metric='euclidean')
    homog_score = homogeneity_score(y.values.reshape(666,), label)
    silh_EM[cluster] = sil_coeff
    homog_EM[cluster] = homog_score
    log_likelihood_EM[cluster] = gmm.score(X)
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(cluster, sil_coeff))
    print("For n_clusters={}, The homogeneity_score is {}".format(cluster, homog_score))
    print("For n_clusters={}, The log_likelihood score is {}".format(cluster, log_likelihood_EM[cluster]))

    
plt.figure()
plt.plot(list(silh_EM.keys()), list(silh_EM.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
plt.show()
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.2935694101921631
# For n_clusters=2, The homogeneity_score is 0.1496523772608504
# For n_clusters=2, The log_likelihood score is 10.359224716443391
# For n_clusters=3, The Silhouette Coefficient is 0.2774248461751386
# For n_clusters=3, The homogeneity_score is 0.14965376289837845
# For n_clusters=3, The log_likelihood score is 13.039297213325671
# For n_clusters=4, The Silhouette Coefficient is 0.33571566237797196
# For n_clusters=4, The homogeneity_score is 0.272789018955694
# For n_clusters=4, The log_likelihood score is 16.600531214485933
# For n_clusters=5, The Silhouette Coefficient is 0.3410058422669218
# For n_clusters=5, The homogeneity_score is 0.34126865669078443
# For n_clusters=5, The log_likelihood score is 17.278152476096295
# For n_clusters=6, The Silhouette Coefficient is 0.4119012763127039
# For n_clusters=6, The homogeneity_score is 0.4876586913316676
# For n_clusters=6, The log_likelihood score is 20.588071750161976
# For n_clusters=7, The Silhouette Coefficient is 0.42917077825140204
# For n_clusters=7, The homogeneity_score is 0.2902686680456545
# For n_clusters=7, The log_likelihood score is 22.34074322171038
# For n_clusters=8, The Silhouette Coefficient is 0.4764811099297593
# For n_clusters=8, The homogeneity_score is 0.3303583078872331
# For n_clusters=8, The log_likelihood score is 23.53360543125096
# For n_clusters=9, The Silhouette Coefficient is 0.5123962353073237
# For n_clusters=9, The homogeneity_score is 0.33055445868991556
# For n_clusters=9, The log_likelihood score is 24.659428008360248
# For n_clusters=10, The Silhouette Coefficient is 0.5484594420731429
# For n_clusters=10, The homogeneity_score is 0.45119120964950016
# For n_clusters=10, The log_likelihood score is 26.48583491491279
# For n_clusters=11, The Silhouette Coefficient is 0.5783897685168157
# For n_clusters=11, The homogeneity_score is 0.4333166642687189
# For n_clusters=11, The log_likelihood score is 26.94921285674586
# For n_clusters=12, The Silhouette Coefficient is 0.6063532988364885
# For n_clusters=12, The homogeneity_score is 0.4764502908341804
# For n_clusters=12, The log_likelihood score is 28.17236965596078
# For n_clusters=13, The Silhouette Coefficient is 0.6332214258513792
# For n_clusters=13, The homogeneity_score is 0.48111755965885183
# For n_clusters=13, The log_likelihood score is 28.896202354763737
# For n_clusters=14, The Silhouette Coefficient is 0.654368019341095
# For n_clusters=14, The homogeneity_score is 0.4971720749228937
# For n_clusters=14, The log_likelihood score is 29.330009110327627
# For n_clusters=15, The Silhouette Coefficient is 0.6712099227270895
# For n_clusters=15, The homogeneity_score is 0.49795391640578046
# For n_clusters=15, The log_likelihood score is 29.71529361331481
# For n_clusters=16, The Silhouette Coefficient is 0.6025637902991298
# For n_clusters=16, The homogeneity_score is 0.5019702467801168
# For n_clusters=16, The log_likelihood score is 30.055244237486153
# For n_clusters=17, The Silhouette Coefficient is 0.6164830962186792
# For n_clusters=17, The homogeneity_score is 0.5019702467801167
# For n_clusters=17, The log_likelihood score is 30.295815915213247
# For n_clusters=18, The Silhouette Coefficient is 0.5979652160181124
# For n_clusters=18, The homogeneity_score is 0.5029010165347592
# For n_clusters=18, The log_likelihood score is 30.34711661612071
# For n_clusters=19, The Silhouette Coefficient is 0.5987496432840654
# For n_clusters=19, The homogeneity_score is 0.5079364049426515
# For n_clusters=19, The log_likelihood score is 30.648904691845903
# For n_clusters=20, The Silhouette Coefficient is 0.5613078126042733
# For n_clusters=20, The homogeneity_score is 0.5086389931045584
# For n_clusters=20, The log_likelihood score is 30.794192185275538
# For n_clusters=21, The Silhouette Coefficient is 0.40692607408270154
# For n_clusters=21, The homogeneity_score is 0.5090515764870122
# For n_clusters=21, The log_likelihood score is 31.001151034424044
# For n_clusters=22, The Silhouette Coefficient is 0.5156765124199938
# For n_clusters=22, The homogeneity_score is 0.5101927450556107
# For n_clusters=22, The log_likelihood score is 31.040779836805168
# For n_clusters=23, The Silhouette Coefficient is 0.5063068022671297
# For n_clusters=23, The homogeneity_score is 0.5125158571040519
# For n_clusters=23, The log_likelihood score is 31.138886414470758
# For n_clusters=24, The Silhouette Coefficient is 0.47008008934062184
# For n_clusters=24, The homogeneity_score is 0.5169831346005549
# For n_clusters=24, The log_likelihood score is 31.160594389858222
# For n_clusters=25, The Silhouette Coefficient is 0.5102637275360759
# For n_clusters=25, The homogeneity_score is 0.5174183918461119
# For n_clusters=25, The log_likelihood score is 31.234983175169035
# For n_clusters=26, The Silhouette Coefficient is 0.47994682120969
# For n_clusters=26, The homogeneity_score is 0.5174440046367176
# For n_clusters=26, The log_likelihood score is 31.312599470399185
# For n_clusters=27, The Silhouette Coefficient is 0.43257801142677244
# For n_clusters=27, The homogeneity_score is 0.5257822516473677
# For n_clusters=27, The log_likelihood score is 31.360851383640743
# For n_clusters=28, The Silhouette Coefficient is 0.40235358084772876
# For n_clusters=28, The homogeneity_score is 0.5258078644379733
# For n_clusters=28, The log_likelihood score is 31.43842064721858
# For n_clusters=29, The Silhouette Coefficient is 0.4251902297852499
# For n_clusters=29, The homogeneity_score is 0.5193592132394464
# For n_clusters=29, The log_likelihood score is 31.574353475460136
# For n_clusters=30, The Silhouette Coefficient is 0.4125731575107857
# For n_clusters=30, The homogeneity_score is 0.5197771232656375
# For n_clusters=30, The log_likelihood score is 31.61094285280543

# %%
plt.figure()
plt.plot(list(silh_EM.keys()), list(silh_EM.values()), 'r', label="Silhouette")
plt.plot(list(homog_EM.keys()), list(homog_EM.values()), 'g', label="Homogeneity")
plt.legend()
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
# Out:
# Text(0, 0.5, 'Silhouette Coefficient')

# %% [markdown]
# ### PCA

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from matplotlib import cm
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.covariance import ShrunkCovariance, LedoitWolf
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
X_df = pd.DataFrame(X, columns=credit.columns[:-1])

# %%
explained_variance_ratio=[]
rc_err=[]
for dim in range(1,10):
    pca = PCA(n_components=dim, random_state=44)
    pca.fit_transform(X_df.values)
    
    # reconstruction
    x_prime = pca.fit_transform(X_df.values)
    A = np.linalg.pinv(pca.components_.T)
    reconstructed = np.dot(x_prime, A)
    rc_err.append(mean_squared_error(X_df.values, reconstructed))   
    explained_variance_ratio.append(sum(pca.explained_variance_ratio_))

df=pd.DataFrame({'dim':range(1,10),'cumulative_explained_variance_ratio':explained_variance_ratio, 'rc_err':rc_err})
df
# Out:
#    dim  cumulative_explained_variance_ratio    rc_err
# 0    1                             0.350783  0.215628
# 1    2                             0.592894  0.187541
# 2    3                             0.791455  0.164506
# 3    4                             0.924812  0.149036
# 4    5                             0.960892  0.144850
# 5    6                             0.985310  0.142017
# 6    7                             0.994281  0.140976
# 7    8                             0.997375  0.140618
# 8    9                             1.000000  0.140313

# %%
comp = 4
pca = PCA(n_components=comp, random_state=44)
pca_result = pca.fit_transform(X_df.values)
for i in range(comp):
    field_name = "pca-"+str(i)
    X_df[field_name] = pca_result[:,i]
    credit[field_name] = pca_result[:,i]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
sum(pca.explained_variance_ratio_)
X_pca_4 = pca_result
# Out:
# Explained variation per principal component: [0.37174666 0.25657968 0.21042723 0.1413261 ]

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="pca-0", y="pca-1",
    hue="Approved",
    palette=sns.color_palette("hls", 2),
    data=credit,
    legend="full",
    alpha=0.3
)

# %%
rndperm = np.random.permutation(credit.shape[0])
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=credit.iloc[rndperm,:]["pca-0"], 
    ys=credit.iloc[rndperm,:]["pca-1"], 
    zs=credit.iloc[rndperm,:]["pca-2"], 
    c=credit.iloc[rndperm,:]["Approved"], 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %% [markdown]
# ### KPCA

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=9, random_state=44)
kpca.fit(X_df.values)
explained_variance_ratio = kpca.lambdas_ / np.sum(kpca.lambdas_)
#print(explained_variance_ratio)
explained_variance=[]
for i in range(1,10):
    explained_variance.append( np.sum(explained_variance_ratio[:i]))
    
df=pd.DataFrame({'component':range(1,10),'explained_variance':explained_variance})
df
# Out:
#    component  explained_variance
# 0          1            0.373083
# 1          2            0.630680
# 2          3            0.841996
# 3          4            0.984020
# 4          5            0.991688
# 5          6            0.996878
# 6          7            0.998785
# 7          8            0.999442
# 8          9            1.000000

# %% [markdown]
# ### ICA

# %%
credit = pd.read_csv('crx.data', names=['Male','Age','Debt','YearsEmployed','PriorDefault','Employed','CreditScore','DriversLicense','Income','Approved'],
                  usecols=[0,1,2,7,8,9,10,11,14,15])

credit=credit.replace('t',1)
credit=credit.replace('f',0)
credit=credit.replace('+',1)
credit=credit.replace('-',0)
credit=credit.replace('b',1)
credit=credit.replace('a',0)
credit=credit.replace('?', np.nan)

credit=credit[credit.isnull().any(axis=1)==False]

credit['Age']=credit['Age'].astype('float64')
credit['Income']=credit['Income'].astype('int64')

# %%
from sklearn.decomposition import PCA, FactorAnalysis, FastICA
rc_errors = {}
for dim in range(1,10):
    ica = FastICA(n_components=dim, random_state=44)
    x_prime = ica.fit_transform(X_df.values)
    
    # reconstruction
    A = np.linalg.pinv(ica.components_.T)
    reconstructed = np.dot(x_prime, A)
    rc_err = mean_squared_error(X_df.values, reconstructed)    
    rc_errors[dim] = rc_err
#     print(dim, ": ", rc_err)
plt.figure()
plt.plot(list(rc_errors.keys()), list(rc_errors.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
comp = 4
ica = FastICA(n_components=comp, random_state=44, max_iter=1000)
ica_result = ica.fit_transform(X_df.values)
for i in range(comp):
    field_name = "ica-"+str(i)
    X_df[field_name] = ica_result[:,i]
    credit[field_name] = ica_result[:,i]
X_ica_4 = ica_result
X_ica_4
# Out:
# array([[ 0.03762694, -0.03875358, -0.02933676, -0.02830911],
#        [ 0.03589201, -0.03583928,  0.05387585, -0.03358344],
#        [ 0.03625529,  0.04790871,  0.05796666, -0.04740748],
#        ...,
#        [-0.04531309, -0.05672638,  0.05809469,  0.05531143],
#        [ 0.03432696,  0.02557198, -0.02561752,  0.03674037],
#        [-0.04423911,  0.02553915, -0.0235395 ,  0.03666165]])

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="ica-0", y="ica-1",
    hue="Approved",
    palette=sns.color_palette("hls", 2),
    data=credit,
    legend="full",
    alpha=0.3
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=credit.iloc[rndperm,:]["ica-0"], 
    ys=credit.iloc[rndperm,:]["ica-1"], 
    zs=credit.iloc[rndperm,:]["ica-2"], 
    c=credit.iloc[rndperm,:]["Approved"], 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %% [markdown]
# ### Randomized Projection

# %%
from sklearn.random_projection import GaussianRandomProjection
rc_errors = {}
for dim in range(1,10):
    grp = GaussianRandomProjection(n_components=dim, random_state=44)
    x_prime = grp.fit_transform(X_df.values)
    
    # reconstruction
    A = np.linalg.pinv(grp.components_.T)
    reconstructed = np.dot(x_prime, A)
    rc_err = mean_squared_error(X_df.values, reconstructed)    
    rc_errors[dim] = rc_err
#     print(dim, ": ", rc_err)
plt.figure()
plt.plot(list(rc_errors.keys()), list(rc_errors.values()))
plt.xlabel("Number of dimensions")
plt.ylabel("RMSE")
plt.show()
